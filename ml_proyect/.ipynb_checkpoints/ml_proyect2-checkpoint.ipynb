# %%
import pandas as pd
import numpy as np
# This filters ALL warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\ragod\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ragod\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\ragod\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
#Importacion de datos
df_lici1 = pd.read_excel(r'C:\Users\ragod\Desktop\Contratos2\2021.xlsx', sheet_name='Licitaciones')
df_result1 = pd.read_excel(r'C:\Users\ragod\Desktop\Contratos2\2021.xlsx', sheet_name='Resultados')

# %%
df_lici1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145470 entries, 0 to 145469
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Identificador                145470 non-null  int64
#  1   Link licitación              145470 non-null  object
#  2   Fecha actualización          145470 non-null  datetime64[ns]
#  3   Vigente/Anulada/Archivada    145470 non-null  object
#  4   Valor estimado del contrato  144780 non-null  float64
#  5   CPV                          144131 non-null  object
#  6   Tipo de contrato             145470 non-null  object
#  7   Órgano de Contratación       145470 non-null  object
#  8   Tipo de Administración       145470 non-null  object
#  9   Tipo de procedimiento        145470 non-null  object
#  10  Sistema de contratación      141855 non-null  object
#  11  Subcontratación permitida    20249 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 13.3+ MB

# %%
df_result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180656 entries, 0 to 180655
# Data columns (total 9 columns):
#  #   Column                                                                  Non-Null Count   Dtype
# ---  ------                                                                  --------------   -----
#  0   Identificador                                                           180656 non-null  int64
#  1   Link licitación                                                         180656 non-null  object
#  2   Fecha actualización                                                     180656 non-null  datetime64[ns]
#  3   Resultado licitación/lote                                               180656 non-null  object
#  4   Precio de la oferta más baja por licitación/lote                        91409 non-null   float64
#  5   Precio de la oferta más alta por licitación/lote                        93922 non-null   float64
#  6   Se han excluído ofertas por ser anormalmente bajas por licitación/lote  21950 non-null   float64
#  7   Importe adjudicación sin impuestos licitación/lote                      163306 non-null  float64
#  8   Importe adjudicación con impuestos licitación/lote                      163306 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 12.4+ MB

# %%
#Renombre de columnas
nuevas_col_lici =['identificador','link','fecha',
       'vigencia',
       'precio_lici',
       'cpv',
       'tipo_cont',
       'org_cont',
       'tipo_admi',
        'tipo_pro',
        'sist_cont',
        'subcontratacion']
nuevas_col_result =['identificador', 'link','fecha','resultado',
       'precio_min',
       'precio_max',
       'baja_tem',
       'precio_adj_sin_imp',
       'precio_adj_con_imp']

# %%
df_lici1=df_lici1.rename(columns={k:v for k,v in zip(df_lici1.columns, nuevas_col_lici)})
df_result1=df_result1.rename(columns={k:v for k,v in zip(df_result1.columns, nuevas_col_result)})

# %%
#Eliminacion columnas por no estar en el estudio
df_lici1.drop(['link','fecha','vigencia','org_cont','tipo_admi','subcontratacion'],axis = 1,inplace = True)
df_result1.drop(['link','fecha'],axis = 1,inplace = True)

# %% [markdown]
# Estudio de varibles de df_lici1
#     identificador debe ser cadena ya que es una clave
#     precio_lici contiene nulos.-
#     cpv contiene varios valores.- se reduce a 1
#
# Estudio de variables de df_result1
#     identificador debe ser cadena ya que es una clave
#     figuran valores por lotes.- reducir a un valor solo por identificador sumando campos precio
#     campos precio con vlaor nulo, transformar inicialmente con 0. Con posteriordad, al agrupar se suman. En     el caso de unico valor rellenar min y max con el de ajudicacion.
#     campo baja_temp debe tomar valores 0/1. rellenar los nulos con 0.
#
# Solo se seleccionan los adjudicados de result1, el resto se eliman, asi como los de lici1 de igual identificador

# %%
# Modificaciones de df_lici_1
df_lici2 = df_lici1
df_lici2.identificador = df_lici2.identificador.astype('string')

# %%
#Modifciaciones de df_resutl1
df_result2 = df_result1
df_result2.identificador = df_result2.identificador.astype('string')
df_result2 = df_result2.fillna(0)

# %%
df_lici2.head()
# Out:
#   identificador  precio_lici                                   cpv  \
# 0       1001315      27300.0  63513000;79956000;79952000;79950000;
# 1       1001606     910892.0                             34933000;
# 2       1001783      34034.0                             92600000;
# 3       1002267     240000.0                             98351000;
# 4       1007145    2472400.0                             32524000;
#
#                        tipo_cont                  tipo_pro  sist_cont
# 0                      Servicios  Negociado sin publicidad  No aplica
# 1                    Suministros  Negociado con publicidad        NaN
# 2                      Servicios  Negociado sin publicidad  No aplica
# 3  Gestión de Servicios Públicos                   Abierto        NaN
# 4                    Suministros  Negociado con publicidad        NaN

# %%
df_result2.head()
# Out:
#   identificador   resultado  precio_min  precio_max  baja_tem  \
# 0       8689190  Adjudicado    19816.45    20000.00       0.0
# 1       8723412  Adjudicado    17656.32    18655.68       0.0
# 2       8303894  Adjudicado    49852.00    49852.00       0.0
# 3       8005484  Adjudicado        0.00        0.00       0.0
# 4       8005484  Adjudicado        0.00        0.00       0.0
#
#    precio_adj_sin_imp  precio_adj_con_imp
# 0            20000.00            24200.00
# 1            17656.32            21364.15
# 2            41200.00            49852.00
# 3          8857959.09         10718130.50
# 4          8776679.14         10619781.76

# %%
# Seleccion solo de los adjudicados.
#Aquellos que tienen un lote no adjudicado se eliminan todos por no tener detalle de licitacion
#identificacion no adjudicados en resultados
lista_no_adjudica = df_result2.identificador[df_result2.resultado != 'Adjudicado']
lista_no_adjudica_result_index = df_result2[df_result2.identificador.isin(lista_no_adjudica)].index

#deteccion de no adjuidcados en liccitaciones
lista_no_adjudicados=list(lista_no_adjudica.unique())
lista_no_adjudica_lici_index = df_lici2[df_lici2.identificador.isin(lista_no_adjudicados)].index

#Deteccion de adjudicados
licitaciones_adjudicadas_index=[i for i in df_lici2.index if i not in lista_no_adjudica_lici_index]
resultados_adjudicados_index=[i for i in df_result2.index if i not in lista_no_adjudica_result_index]

# %%
# Eliminacion de no ejecutados
df_lici3 = df_lici2.iloc[licitaciones_adjudicadas_index]
df_result3   = df_result2.iloc[resultados_adjudicados_index]

# %%
# Elimino aquellos adjudicados con precio de adjudicacion 0

df_result3 = df_result3[df_result3.precio_adj_sin_imp != 0]

# %%
# Agrupacion de resultados por identificador

df_result4 = df_result3.groupby('identificador',as_index = False).sum()

# %%
#Asignacion de valors max y min cuando son 0.
df_result4.loc[(df_result4.precio_min==0)&(df_result4.precio_max==0),['precio_min','precio_max']]=df_result4['precio_adj_sin_imp']

# %%
df_result4
# Out:
#        identificador   precio_min   precio_max  baja_tem  precio_adj_sin_imp  \
# 0            1001606    627201.77    627201.77       0.0           627201.77
# 1            1002267    111500.00    111500.00       0.0           111500.00
# 2            1007145   2472399.73   2472399.73       0.0          2472399.73
# 3            1007418   1507220.00   1507220.00       0.0          1507220.00
# 4            1007814    116482.24    149691.36       0.0           116482.24
# ...              ...          ...          ...       ...                 ...
# 106416        985152    204744.80    204744.80       0.0           204744.80
# 106417        985194  15205406.79  15205406.79       0.0         15205406.79
# 106418        991030    935574.20    935574.20       0.0           935574.20
# 106419        996489    262800.00    262800.00       0.0           262800.00
# 106420        996620    193528.63    193528.63       0.0           193528.63
#
#         precio_adj_con_imp
# 0                758914.14
# 1                111500.00
# 2               2933884.48
# 3               1823736.20
# 4                124636.00
# ...                    ...
# 106416           247741.21
# 106417         18398542.22
# 106418          1001064.39
# 106419           317988.00
# 106420           207075.63
#
# [106421 rows x 6 columns]

# %%
identificador_result = list(df_result4.identificador)

# %%
df_lici3[df_lici3['identificador'].isin ( df_result4.identificador)]
# Out:
#        identificador  precio_lici                          cpv  \
# 1            1001606    910892.00                    34933000;
# 3            1002267    240000.00                    98351000;
# 4            1007145   2472400.00                    32524000;
# 5            1007418   3720000.00                    90910000;
# 6            1007814    261584.00                    98341130;
# ...              ...          ...                          ...
# 145464        985152   1322880.00                    60160000;
# 145465        985194  27239507.00                    45234110;
# 145466        991030   1383385.39                    45331000;
# 145468        996489    554040.00                    50413200;
# 145469        996620          NaN  71311100;71318000;71322000;
#
#                             tipo_cont                  tipo_pro  sist_cont
# 1                         Suministros  Negociado con publicidad        NaN
# 3       Gestión de Servicios Públicos                   Abierto        NaN
# 4                         Suministros  Negociado con publicidad        NaN
# 5                           Servicios                   Abierto        NaN
# 6                           Servicios           Normas internas  No aplica
# ...                               ...                       ...        ...
# 145464                      Servicios  Negociado con publicidad        NaN
# 145465                          Obras                   Abierto        NaN
# 145466                          Obras  Negociado con publicidad  No aplica
# 145468                      Servicios                   Abierto        NaN
# 145469                      Servicios                   Abierto        NaN
#
# [106421 rows x 6 columns]

# %%
df_final=df_lici3.join(df_result4.set_index('identificador'), on ='identificador', how = 'right')

# %%
# elimino licitaciones sin precio
df_final2=df_final[df_final.precio_lici.isnull()== False]

#elimino licitaciones menores que el adjudicado

df_final2 = df_final2[(df_final2.precio_lici < df_final2.precio_adj_sin_imp) == False]

#elimino licitaciones con importe 0

df_final2 = df_final2[df_final2.precio_lici != 0 ]

# elimino las licitaciones con cpv nulo

df_final2=df_final2[df_final2.cpv.isnull()== False]

# %%
df_final2
# Out:
#        identificador  precio_lici                          cpv  \
# 1            1001606    910892.00                    34933000;
# 3            1002267    240000.00                    98351000;
# 4            1007145   2472400.00                    32524000;
# 5            1007418   3720000.00                    90910000;
# 6            1007814    261584.00                    98341130;
# ...              ...          ...                          ...
# 145463        984860  11061404.96  45252130;90481000;45259100;
# 145464        985152   1322880.00                    60160000;
# 145465        985194  27239507.00                    45234110;
# 145466        991030   1383385.39                    45331000;
# 145468        996489    554040.00                    50413200;
#
#                             tipo_cont                  tipo_pro  sist_cont  \
# 1                         Suministros  Negociado con publicidad        NaN
# 3       Gestión de Servicios Públicos                   Abierto        NaN
# 4                         Suministros  Negociado con publicidad        NaN
# 5                           Servicios                   Abierto        NaN
# 6                           Servicios           Normas internas  No aplica
# ...                               ...                       ...        ...
# 145463  Gestión de Servicios Públicos                   Abierto        NaN
# 145464                      Servicios  Negociado con publicidad        NaN
# 145465                          Obras                   Abierto        NaN
# 145466                          Obras  Negociado con publicidad  No aplica
# 145468                      Servicios                   Abierto        NaN
#
#          precio_min   precio_max  baja_tem  precio_adj_sin_imp  \
# 1         627201.77    627201.77       0.0           627201.77
# 3         111500.00    111500.00       0.0           111500.00
# 4        2472399.73   2472399.73       0.0          2472399.73
# 5        1507220.00   1507220.00       0.0          1507220.00
# 6         116482.24    149691.36       0.0           116482.24
# ...             ...          ...       ...                 ...
# 145463   3390923.01   3390923.01       0.0          3390923.01
# 145464    204744.80    204744.80       0.0           204744.80
# 145465  15205406.79  15205406.79       0.0         15205406.79
# 145466    935574.20    935574.20       0.0           935574.20
# 145468    262800.00    262800.00       0.0           262800.00
#
#         precio_adj_con_imp
# 1                758914.14
# 3                111500.00
# 4               2933884.48
# 5               1823736.20
# 6                124636.00
# ...                    ...
# 145463          3765087.82
# 145464           247741.21
# 145465         18398542.22
# 145466          1001064.39
# 145468           317988.00
#
# [101300 rows x 11 columns]

# %%
df_final2['porcen_adjudic'] = df_final2['precio_adj_sin_imp']/df_final2['precio_lici']

# %%
df_final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101300 entries, 1 to 145468
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   identificador       101300 non-null  string
#  1   precio_lici         101300 non-null  float64
#  2   cpv                 101300 non-null  object
#  3   tipo_cont           101300 non-null  object
#  4   tipo_pro            101300 non-null  object
#  5   sist_cont           98602 non-null   object
#  6   precio_min          101300 non-null  float64
#  7   precio_max          101300 non-null  float64
#  8   baja_tem            101300 non-null  float64
#  9   precio_adj_sin_imp  101300 non-null  float64
#  10  precio_adj_con_imp  101300 non-null  float64
#  11  porcen_adjudic      101300 non-null  float64
# dtypes: float64(7), object(4), string(1)
# memory usage: 10.0+ MB

# %%
df_final2.groupby('tipo_pro').count()
# Out:
#                             identificador  precio_lici    cpv  tipo_cont  \
# tipo_pro
# Abierto                             34370        34370  34370      34370
# Abierto simplificado                37253        37253  37253      37253
# Derivado de acuerdo marco           13424        13424  13424      13424
# Diálogo competitivo                     5            5      5          5
# Licitación con negociación             86           86     86         86
# Negociado con publicidad              844          844    844        844
# Negociado sin publicidad            12445        12445  12445      12445
# Normas internas                      2178         2178   2178       2178
# Otros                                  13           13     13         13
# Restringido                           682          682    682        682
#
#                             sist_cont  precio_min  precio_max  baja_tem  \
# tipo_pro
# Abierto                         32596       34370       34370     34370
# Abierto simplificado            36651       37253       37253     37253
# Derivado de acuerdo marco       13424       13424       13424     13424
# Diálogo competitivo                 4           5           5         5
# Licitación con negociación         85          86          86        86
# Negociado con publicidad          773         844         844       844
# Negociado sin publicidad        12278       12445       12445     12445
# Normas internas                  2131        2178        2178      2178
# Otros                              13          13          13        13
# Restringido                       647         682         682       682
#
#                             precio_adj_sin_imp  precio_adj_con_imp  \
# tipo_pro
# Abierto                                  34370               34370
# Abierto simplificado                     37253               37253
# Derivado de acuerdo marco                13424               13424
# Diálogo competitivo                          5                   5
# Licitación con negociación                  86                  86
# Negociado con publicidad                   844                 844
# Negociado sin publicidad                 12445               12445
# Normas internas                           2178                2178
# Otros                                       13                  13
# Restringido                                682                 682
#
#                             porcen_adjudic
# tipo_pro
# Abierto                              34370
# Abierto simplificado                 37253
# Derivado de acuerdo marco            13424
# Diálogo competitivo                      5
# Licitación con negociación              86
# Negociado con publicidad               844
# Negociado sin publicidad             12445
# Normas internas                       2178
# Otros                                   13
# Restringido                            682

# %%
# Par no distorsionar información. El estudio se centrará en los procedimientos de contrato más comunes.

df_final3 =df_final2[(df_final2.tipo_pro=='Abierto')|(df_final2.tipo_pro =='Abierto simplificado')]

# %%
df_final3.describe().style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff968">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff968_level0_col0" class="col_heading level0 col0" >precio_lici</th>
#       <th id="T_ff968_level0_col1" class="col_heading level0 col1" >precio_min</th>
#       <th id="T_ff968_level0_col2" class="col_heading level0 col2" >precio_max</th>
#       <th id="T_ff968_level0_col3" class="col_heading level0 col3" >baja_tem</th>
#       <th id="T_ff968_level0_col4" class="col_heading level0 col4" >precio_adj_sin_imp</th>
#       <th id="T_ff968_level0_col5" class="col_heading level0 col5" >precio_adj_con_imp</th>
#       <th id="T_ff968_level0_col6" class="col_heading level0 col6" >porcen_adjudic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff968_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ff968_row0_col0" class="data row0 col0" >71623.00</td>
#       <td id="T_ff968_row0_col1" class="data row0 col1" >71623.00</td>
#       <td id="T_ff968_row0_col2" class="data row0 col2" >71623.00</td>
#       <td id="T_ff968_row0_col3" class="data row0 col3" >71623.00</td>
#       <td id="T_ff968_row0_col4" class="data row0 col4" >71623.00</td>
#       <td id="T_ff968_row0_col5" class="data row0 col5" >71623.00</td>
#       <td id="T_ff968_row0_col6" class="data row0 col6" >71623.00</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ff968_row1_col0" class="data row1 col0" >853402.28</td>
#       <td id="T_ff968_row1_col1" class="data row1 col1" >402579.76</td>
#       <td id="T_ff968_row1_col2" class="data row1 col2" >470219.83</td>
#       <td id="T_ff968_row1_col3" class="data row1 col3" >0.02</td>
#       <td id="T_ff968_row1_col4" class="data row1 col4" >457855.78</td>
#       <td id="T_ff968_row1_col5" class="data row1 col5" >533858.89</td>
#       <td id="T_ff968_row1_col6" class="data row1 col6" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ff968_row2_col0" class="data row2 col0" >10911458.68</td>
#       <td id="T_ff968_row2_col1" class="data row2 col1" >6846622.18</td>
#       <td id="T_ff968_row2_col2" class="data row2 col2" >7106293.08</td>
#       <td id="T_ff968_row2_col3" class="data row2 col3" >0.34</td>
#       <td id="T_ff968_row2_col4" class="data row2 col4" >7217779.23</td>
#       <td id="T_ff968_row2_col5" class="data row2 col5" >8077962.57</td>
#       <td id="T_ff968_row2_col6" class="data row2 col6" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_ff968_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_ff968_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_ff968_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_ff968_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_ff968_row3_col4" class="data row3 col4" >0.01</td>
#       <td id="T_ff968_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_ff968_row3_col6" class="data row3 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_ff968_row4_col0" class="data row4 col0" >38811.50</td>
#       <td id="T_ff968_row4_col1" class="data row4 col1" >14950.00</td>
#       <td id="T_ff968_row4_col2" class="data row4 col2" >22500.00</td>
#       <td id="T_ff968_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_ff968_row4_col4" class="data row4 col4" >21735.33</td>
#       <td id="T_ff968_row4_col5" class="data row4 col5" >25289.00</td>
#       <td id="T_ff968_row4_col6" class="data row4 col6" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_ff968_row5_col0" class="data row5 col0" >89902.35</td>
#       <td id="T_ff968_row5_col1" class="data row5 col1" >46500.00</td>
#       <td id="T_ff968_row5_col2" class="data row5 col2" >58182.75</td>
#       <td id="T_ff968_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_ff968_row5_col4" class="data row5 col4" >55158.55</td>
#       <td id="T_ff968_row5_col5" class="data row5 col5" >65013.30</td>
#       <td id="T_ff968_row5_col6" class="data row5 col6" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_ff968_row6_col0" class="data row6 col0" >249989.00</td>
#       <td id="T_ff968_row6_col1" class="data row6 col1" >135534.10</td>
#       <td id="T_ff968_row6_col2" class="data row6 col2" >164189.17</td>
#       <td id="T_ff968_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_ff968_row6_col4" class="data row6 col4" >155486.50</td>
#       <td id="T_ff968_row6_col5" class="data row6 col5" >182713.31</td>
#       <td id="T_ff968_row6_col6" class="data row6 col6" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_ff968_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_ff968_row7_col0" class="data row7 col0" >1584728506.91</td>
#       <td id="T_ff968_row7_col1" class="data row7 col1" >1462355341.81</td>
#       <td id="T_ff968_row7_col2" class="data row7 col2" >1508578001.56</td>
#       <td id="T_ff968_row7_col3" class="data row7 col3" >39.00</td>
#       <td id="T_ff968_row7_col4" class="data row7 col4" >1487654353.47</td>
#       <td id="T_ff968_row7_col5" class="data row7 col5" >1636419788.82</td>
#       <td id="T_ff968_row7_col6" class="data row7 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_final3.groupby('tipo_cont').count()
# Out:
#                                                     identificador  \
# tipo_cont
# Administrativo especial                                       152
# Colaboración entre el sector público y sector p...              6
# Concesión de Obras                                             16
# Concesión de Obras Públicas                                     2
# Concesión de Servicios                                        464
# Gestión de Servicios Públicos                                  44
# Obras                                                       16816
# Patrimonial                                                   292
# Privado                                                       824
# Servicios                                                   33388
# Suministros                                                 19619
#
#                                                     precio_lici    cpv  \
# tipo_cont
# Administrativo especial                                     152    152
# Colaboración entre el sector público y sector p...            6      6
# Concesión de Obras                                           16     16
# Concesión de Obras Públicas                                   2      2
# Concesión de Servicios                                      464    464
# Gestión de Servicios Públicos                                44     44
# Obras                                                     16816  16816
# Patrimonial                                                 292    292
# Privado                                                     824    824
# Servicios                                                 33388  33388
# Suministros                                               19619  19619
#
#                                                     tipo_pro  sist_cont  \
# tipo_cont
# Administrativo especial                                  152        140
# Colaboración entre el sector público y sector p...         6          6
# Concesión de Obras                                        16         16
# Concesión de Obras Públicas                                2          2
# Concesión de Servicios                                   464        451
# Gestión de Servicios Públicos                             44         30
# Obras                                                  16816      16395
# Patrimonial                                              292        291
# Privado                                                  824        804
# Servicios                                              33388      31863
# Suministros                                            19619      19249
#
#                                                     precio_min  precio_max  \
# tipo_cont
# Administrativo especial                                    152         152
# Colaboración entre el sector público y sector p...           6           6
# Concesión de Obras                                          16          16
# Concesión de Obras Públicas                                  2           2
# Concesión de Servicios                                     464         464
# Gestión de Servicios Públicos                               44          44
# Obras                                                    16816       16816
# Patrimonial                                                292         292
# Privado                                                    824         824
# Servicios                                                33388       33388
# Suministros                                              19619       19619
#
#                                                     baja_tem  \
# tipo_cont
# Administrativo especial                                  152
# Colaboración entre el sector público y sector p...         6
# Concesión de Obras                                        16
# Concesión de Obras Públicas                                2
# Concesión de Servicios                                   464
# Gestión de Servicios Públicos                             44
# Obras                                                  16816
# Patrimonial                                              292
# Privado                                                  824
# Servicios                                              33388
# Suministros                                            19619
#
#                                                     precio_adj_sin_imp  \
# tipo_cont
# Administrativo especial                                            152
# Colaboración entre el sector público y sector p...                   6
# Concesión de Obras                                                  16
# Concesión de Obras Públicas                                          2
# Concesión de Servicios                                             464
# Gestión de Servicios Públicos                                       44
# Obras                                                            16816
# Patrimonial                                                        292
# Privado                                                            824
# Servicios                                                        33388
# Suministros                                                      19619
#
#                                                     precio_adj_con_imp  \
# tipo_cont
# Administrativo especial                                            152
# Colaboración entre el sector público y sector p...                   6
# Concesión de Obras                                                  16
# Concesión de Obras Públicas                                          2
# Concesión de Servicios                                             464
# Gestión de Servicios Públicos                                       44
# Obras                                                            16816
# Patrimonial                                                        292
# Privado                                                            824
# Servicios                                                        33388
# Suministros                                                      19619
#
#                                                     porcen_adjudic
# tipo_cont
# Administrativo especial                                        152
# Colaboración entre el sector público y sector p...               6
# Concesión de Obras                                              16
# Concesión de Obras Públicas                                      2
# Concesión de Servicios                                         464
# Gestión de Servicios Públicos                                   44
# Obras                                                        16816
# Patrimonial                                                    292
# Privado                                                        824
# Servicios                                                    33388
# Suministros                                                  19619

# %%
# Seleccionamos los tipos de contratos más comunes: Obras, Suministros y Servicios

df_final4 = df_final3[(df_final3.tipo_cont =='Obras')|(df_final3.tipo_cont =='Suministros')|(df_final3.tipo_cont =='Servicios')]

# %%
df_final4.describe().style.format(precision = 2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2097">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2097_level0_col0" class="col_heading level0 col0" >precio_lici</th>
#       <th id="T_a2097_level0_col1" class="col_heading level0 col1" >precio_min</th>
#       <th id="T_a2097_level0_col2" class="col_heading level0 col2" >precio_max</th>
#       <th id="T_a2097_level0_col3" class="col_heading level0 col3" >baja_tem</th>
#       <th id="T_a2097_level0_col4" class="col_heading level0 col4" >precio_adj_sin_imp</th>
#       <th id="T_a2097_level0_col5" class="col_heading level0 col5" >precio_adj_con_imp</th>
#       <th id="T_a2097_level0_col6" class="col_heading level0 col6" >porcen_adjudic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2097_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a2097_row0_col0" class="data row0 col0" >69823.00</td>
#       <td id="T_a2097_row0_col1" class="data row0 col1" >69823.00</td>
#       <td id="T_a2097_row0_col2" class="data row0 col2" >69823.00</td>
#       <td id="T_a2097_row0_col3" class="data row0 col3" >69823.00</td>
#       <td id="T_a2097_row0_col4" class="data row0 col4" >69823.00</td>
#       <td id="T_a2097_row0_col5" class="data row0 col5" >69823.00</td>
#       <td id="T_a2097_row0_col6" class="data row0 col6" >69823.00</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_a2097_row1_col0" class="data row1 col0" >814211.98</td>
#       <td id="T_a2097_row1_col1" class="data row1 col1" >395616.21</td>
#       <td id="T_a2097_row1_col2" class="data row1 col2" >463602.27</td>
#       <td id="T_a2097_row1_col3" class="data row1 col3" >0.02</td>
#       <td id="T_a2097_row1_col4" class="data row1 col4" >445106.87</td>
#       <td id="T_a2097_row1_col5" class="data row1 col5" >520684.69</td>
#       <td id="T_a2097_row1_col6" class="data row1 col6" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_a2097_row2_col0" class="data row2 col0" >9950806.94</td>
#       <td id="T_a2097_row2_col1" class="data row2 col1" >6702362.80</td>
#       <td id="T_a2097_row2_col2" class="data row2 col2" >6970779.21</td>
#       <td id="T_a2097_row2_col3" class="data row2 col3" >0.34</td>
#       <td id="T_a2097_row2_col4" class="data row2 col4" >6894640.47</td>
#       <td id="T_a2097_row2_col5" class="data row2 col5" >7724554.55</td>
#       <td id="T_a2097_row2_col6" class="data row2 col6" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_a2097_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_a2097_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_a2097_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_a2097_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_a2097_row3_col4" class="data row3 col4" >0.01</td>
#       <td id="T_a2097_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_a2097_row3_col6" class="data row3 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_a2097_row4_col0" class="data row4 col0" >39480.41</td>
#       <td id="T_a2097_row4_col1" class="data row4 col1" >15600.00</td>
#       <td id="T_a2097_row4_col2" class="data row4 col2" >23364.49</td>
#       <td id="T_a2097_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_a2097_row4_col4" class="data row4 col4" >22502.47</td>
#       <td id="T_a2097_row4_col5" class="data row4 col5" >26269.21</td>
#       <td id="T_a2097_row4_col6" class="data row4 col6" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_a2097_row5_col0" class="data row5 col0" >90000.00</td>
#       <td id="T_a2097_row5_col1" class="data row5 col1" >47700.00</td>
#       <td id="T_a2097_row5_col2" class="data row5 col2" >59385.58</td>
#       <td id="T_a2097_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_a2097_row5_col4" class="data row5 col4" >56412.52</td>
#       <td id="T_a2097_row5_col5" class="data row5 col5" >66545.16</td>
#       <td id="T_a2097_row5_col6" class="data row5 col6" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_a2097_row6_col0" class="data row6 col0" >250605.47</td>
#       <td id="T_a2097_row6_col1" class="data row6 col1" >137942.40</td>
#       <td id="T_a2097_row6_col2" class="data row6 col2" >166368.42</td>
#       <td id="T_a2097_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_a2097_row6_col4" class="data row6 col4" >158288.40</td>
#       <td id="T_a2097_row6_col5" class="data row6 col5" >186370.79</td>
#       <td id="T_a2097_row6_col6" class="data row6 col6" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_a2097_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_a2097_row7_col0" class="data row7 col0" >1584728506.91</td>
#       <td id="T_a2097_row7_col1" class="data row7 col1" >1462355341.81</td>
#       <td id="T_a2097_row7_col2" class="data row7 col2" >1508578001.56</td>
#       <td id="T_a2097_row7_col3" class="data row7 col3" >39.00</td>
#       <td id="T_a2097_row7_col4" class="data row7 col4" >1487654353.47</td>
#       <td id="T_a2097_row7_col5" class="data row7 col5" >1636419788.82</td>
#       <td id="T_a2097_row7_col6" class="data row7 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>
