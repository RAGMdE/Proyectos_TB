# %% [markdown]
# Se pretende obtener el listado de errores en formato csv de un fichero pdf

# %%
# !pip install pymupdf

# %%
import pandas as pd
import numpy as np
import fitz

# %%
doc = fitz.open(r'C:/Users/ragod/OneDrive/Escritorio/2021_sin_contabilizar.pdf') 
#lectura d ela pagina de clasificaci
lista =[]
for p in range(0,108):
    pagina = doc[p]
    paras = pagina.get_text('blocks')
    # la información empieza del bloque 13  al 33 apartir del elemento 5
    for i in range(14, len(paras)-1):
        lista.append(paras[i][4])

# %%
lista[2949]
# Out:
# '00159222B10009944\n000B30893440\n2002300\n00159221310085654\n20221417  122M1  22105\n2,64\n173062100866\n'

# %%
lista2=[]
for n in range(0, 2950):
    lista2.append(lista[n])

# %%
lista2[2949]
# Out:
# '00159222B10009944\n000B30893440\n2002300\n00159221310085654\n20221417  122M1  22105\n2,64\n173062100866\n'

# %%
for n in range(len(lista2)):
    xx = lista2[n][18:21]
    if xx == '200':
        lista2[n]=lista2[n][:18]+'*\n*\n'+lista2[n][18:]

# %%
for n in range(len(lista2)):
    xx = lista2[n][18:21]
    if xx == '000':
        lista2[n]=lista2[n][:18]+'*\n'+lista2[n][18:]

# %%
for n in range(len(lista2)):
    xx = lista2[n][36:39]
    if xx == '200':
        lista2[n]=lista2[n][:36]+'*\n'+lista2[n][36:]

# %%
lista3 =[]
for n in range(0, len(lista2)):
    lista3.append(lista2[n].split('\n'))

# %%
lista3[1]
# Out:
# ['00159222B10008779',
#  '00159221310085846',
#  '000B85711828',
#  '2002300',
#  '00159221310085846',
#  '20221401  121M2  630',
#  '3.630,00',
#  '013022100834',
#  '1991141040001000017',
#  '']

# %%
for n in range(len(lista3)):
    lista3[n][6]= lista3[n][6].replace('.', '')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-9a51e5d09a54> in <module>
#       1 for n in range(len(lista3)):
# ----> 2     lista3[n][6]= lista3[n][6].replace('.', '')
#
# IndexError: list index out of range

# %%
for j in range(0,len(lista3)):
    lista3[j][6]= lista3[j][6].replace(',', '.')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-d336ded7c8bc> in <module>
#       1 for j in range(0,len(lista3)):
# ----> 2     lista3[j][6]= lista3[j][6].replace(',', '.')
#
# IndexError: list index out of range

# %%
lista3[0][6]
# Out:
# '3630.00'

# %%
df =pd.DataFrame(lista3)

# %%
df.columns =['num_paralela','num_x','tercero','cod_op','op_2021','apli','importe','exp_gasto','exp_gestor','x']

# %%
df
# Out:
#            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli  importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630  3630.00  013022100834
# 1     00159221310085846    20221401  121M2  630  3630.00  013022100834
# 2     00159221310009010    20221401  121M2  630     0.04  101000000166
# 3     00159221310057742    20221401  121M2  630     0.04  013022100187
# 4     00159221310097634    20221401  121M2  630    32.90  013022100968
# ...                 ...                     ...      ...           ...
# 2945  00159221310049393  20221417  122N1  22105    12,21  173052100328
# 2946  00159221310044074  20221417  122M1  22105    15,61  173052100337
# 2947  00159221310059903  20221417  122M1  22105    15,61  173052100337
# 2948  00159221310080419  20221417  122M1  22105     2,64  173062100866
# 2949  00159221310085654  20221417  122M1  22105     2,64  173062100866
#
#                exp_gestor     x
# 0     1991141040001000017
# 1     1991141040001000017
# 2     1991141040004000069
# 3     1991141040004000069
# 4     1991141040004000085
# ...                   ...   ...
# 2945                       None
# 2946                       None
# 2947                       None
# 2948                       None
# 2949                       None
#
# [2950 rows x 10 columns]

# %%
df.pop('x')
# Out:
# 0
# 1
# 2
# 3
# 4
#         ...
# 2945    None
# 2946    None
# 2947    None
# 2948    None
# 2949    None
# Name: x, Length: 2950, dtype: object

# %%
df[df['num_paralela']=='Total']
# Out:
#      num_paralela          num_x         tercero cod_op op_2021  apli importe  \
# 708         Total   2.429.061,53  14 Servicio 01           None  None    None
# 1238        Total   1.986.045,32  14 Servicio 02           None  None    None
# 2928        Total  12.674.206,59  14 Servicio 03           None  None    None
# 2932        Total       7.926,32  14 Servicio 12           None  None    None
#
#      exp_gasto exp_gestor
# 708       None       None
# 1238      None       None
# 2928      None       None
# 2932      None       None

# %%
df[df['importe'].isnull()]
# Out:
#             num_paralela          num_x         tercero cod_op op_2021  apli  \
# 708                Total   2.429.061,53  14 Servicio 01           None  None
# 709   Total Compromisos:   1.342.344,38                   None    None  None
# 1238               Total   1.986.045,32  14 Servicio 02           None  None
# 1239  Total Compromisos:     948.490,01                   None    None  None
# 2928               Total  12.674.206,59  14 Servicio 03           None  None
# 2929  Total Compromisos:   5.478.865,36                   None    None  None
# 2932               Total       7.926,32  14 Servicio 12           None  None
# 2933  Total Compromisos:       3.963,16                   None    None  None
#
#      importe exp_gasto exp_gestor
# 708     None      None       None
# 709     None      None       None
# 1238    None      None       None
# 1239    None      None       None
# 2928    None      None       None
# 2929    None      None       None
# 2932    None      None       None
# 2933    None      None       None

# %%
clean_index=[i for i in df.index if i not in df[df['importe'].isnull()].index]  # selecciono los indices del df que no estan en outliers
clean_index

df = df.iloc[clean_index]

# %%
df.reindex
# Out:
# <bound method DataFrame.reindex of            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli  importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630  3630.00  013022100834
# 1     00159221310085846    20221401  121M2  630  3630.00  013022100834
# 2     00159221310009010    20221401  121M2  630     0.04  101000000166
# 3     00159221310057742    20221401  121M2  630     0.04  013022100187
# 4     00159221310097634    20221401  121M2  630    32.90  013022100968
# ...                 ...                     ...      ...           ...
# 2945  00159221310049393  20221417  122N1  22105    12,21  173052100328
# 2946  00159221310044074  20221417  122M1  22105    15,61  173052100337
# 2947  00159221310059903  20221417  122M1  22105    15,61  173052100337
# 2948  00159221310080419  20221417  122M1  22105     2,64  173062100866
# 2949  00159221310085654  20221417  122M1  22105     2,64  173062100866
#
#                exp_gestor
# 0     1991141040001000017
# 1     1991141040001000017
# 2     1991141040004000069
# 3     1991141040004000069
# 4     1991141040004000085
# ...                   ...
# 2945
# 2946
# 2947
# 2948
# 2949
#
# [2942 rows x 9 columns]>

# %%
#df.to_csv('df_final.csv', index = False)

# %%
df.dtypes
# Out:
# num_paralela    object
# num_x           object
# tercero         object
# cod_op          object
# op_2021         object
# apli            object
# importe         object
# exp_gasto       object
# exp_gestor      object
# dtype: object

# %%
nan_cols=df.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Series([], dtype: int64)

# %%
df
# Out:
#            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli  importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630  3630.00  013022100834
# 1     00159221310085846    20221401  121M2  630  3630.00  013022100834
# 2     00159221310009010    20221401  121M2  630     0.04  101000000166
# 3     00159221310057742    20221401  121M2  630     0.04  013022100187
# 4     00159221310097634    20221401  121M2  630    32.90  013022100968
# ...                 ...                     ...      ...           ...
# 2945  00159221310049393  20221417  122N1  22105    12,21  173052100328
# 2946  00159221310044074  20221417  122M1  22105    15,61  173052100337
# 2947  00159221310059903  20221417  122M1  22105    15,61  173052100337
# 2948  00159221310080419  20221417  122M1  22105     2,64  173062100866
# 2949  00159221310085654  20221417  122M1  22105     2,64  173062100866
#
#                exp_gestor
# 0     1991141040001000017
# 1     1991141040001000017
# 2     1991141040004000069
# 3     1991141040004000069
# 4     1991141040004000085
# ...                   ...
# 2945
# 2946
# 2947
# 2948
# 2949
#
# [2942 rows x 9 columns]

# %%
df['importe']=df['importe'].apply(lambda x: x.replace('.',''))
# Out:
# <ipython-input-40-74e27a6579c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['importe']=df['importe'].apply(lambda x: x.replace('.',''))

# %%
df['importe']
# Out:
# 0       363000
# 1       363000
# 2          004
# 3          004
# 4         3290
#          ...
# 2945     12,21
# 2946     15,61
# 2947     15,61
# 2948      2,64
# 2949      2,64
# Name: importe, Length: 2942, dtype: object

# %%
df['importe']=df['importe'].apply(lambda x: x.replace(',','.'))
# Out:
# <ipython-input-42-edf56f6be89b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['importe']=df['importe'].apply(lambda x: x.replace(',','.'))

# %%
df['importe']
# Out:
# 0       363000
# 1       363000
# 2          004
# 3          004
# 4         3290
#          ...
# 2945     12.21
# 2946     15.61
# 2947     15.61
# 2948      2.64
# 2949      2.64
# Name: importe, Length: 2942, dtype: object

# %%
nan_cols=df.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Series([], dtype: int64)

# %%
df.reindex()
# Out:
#            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630  363000  013022100834
# 1     00159221310085846    20221401  121M2  630  363000  013022100834
# 2     00159221310009010    20221401  121M2  630     004  101000000166
# 3     00159221310057742    20221401  121M2  630     004  013022100187
# 4     00159221310097634    20221401  121M2  630    3290  013022100968
# ...                 ...                     ...     ...           ...
# 2945  00159221310049393  20221417  122N1  22105   12.21  173052100328
# 2946  00159221310044074  20221417  122M1  22105   15.61  173052100337
# 2947  00159221310059903  20221417  122M1  22105   15.61  173052100337
# 2948  00159221310080419  20221417  122M1  22105    2.64  173062100866
# 2949  00159221310085654  20221417  122M1  22105    2.64  173062100866
#
#                exp_gestor
# 0     1991141040001000017
# 1     1991141040001000017
# 2     1991141040004000069
# 3     1991141040004000069
# 4     1991141040004000085
# ...                   ...
# 2945
# 2946
# 2947
# 2948
# 2949
#
# [2942 rows x 9 columns]

# %%
df['SP'] = df['apli'].apply(lambda x: x[6:8])
# Out:
# <ipython-input-46-9fdde3680d40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SP'] = df['apli'].apply(lambda x: x[6:8])

# %%
df['importe'] = df['importe'].astype(float)
# Out:
# <ipython-input-47-a2bebfaf1d01>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['importe'] = df['importe'].astype(float)

# %%
df
# Out:
#            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli    importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630  363000.00  013022100834
# 1     00159221310085846    20221401  121M2  630  363000.00  013022100834
# 2     00159221310009010    20221401  121M2  630       4.00  101000000166
# 3     00159221310057742    20221401  121M2  630       4.00  013022100187
# 4     00159221310097634    20221401  121M2  630    3290.00  013022100968
# ...                 ...                     ...        ...           ...
# 2945  00159221310049393  20221417  122N1  22105      12.21  173052100328
# 2946  00159221310044074  20221417  122M1  22105      15.61  173052100337
# 2947  00159221310059903  20221417  122M1  22105      15.61  173052100337
# 2948  00159221310080419  20221417  122M1  22105       2.64  173062100866
# 2949  00159221310085654  20221417  122M1  22105       2.64  173062100866
#
#                exp_gestor  SP
# 0     1991141040001000017  01
# 1     1991141040001000017  01
# 2     1991141040004000069  01
# 3     1991141040004000069  01
# 4     1991141040004000085  01
# ...                   ...  ..
# 2945                       17
# 2946                       17
# 2947                       17
# 2948                       17
# 2949                       17
#
# [2942 rows x 10 columns]

# %%
df.to_csv('df_sin_contabilizar.csv', index = False)

# %%
df['importe'].sum()
# Out:
# 257574647.47

# %%
df.groupby(['SP']).sum(['importe']).style.format({"importe": "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_a8592_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importe</th>    </tr>    <tr>        <th class="index_name level0" >SP</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8592_level0_row0" class="row_heading level0 row0" >01</th>
#                         <td id="T_a8592_row0_col0" class="data row0 col0" >242906153.00</td>
#             </tr>
#             <tr>
#                         <th id="T_a8592_level0_row1" class="row_heading level0 row1" >02</th>
#                         <td id="T_a8592_row1_col0" class="data row1 col0" >1986045.32</td>
#             </tr>
#             <tr>
#                         <th id="T_a8592_level0_row2" class="row_heading level0 row2" >03</th>
#                         <td id="T_a8592_row2_col0" class="data row2 col0" >12674206.59</td>
#             </tr>
#             <tr>
#                         <th id="T_a8592_level0_row3" class="row_heading level0 row3" >12</th>
#                         <td id="T_a8592_row3_col0" class="data row3 col0" >7926.32</td>
#             </tr>
#             <tr>
#                         <th id="T_a8592_level0_row4" class="row_heading level0 row4" >17</th>
#                         <td id="T_a8592_row4_col0" class="data row4 col0" >316.24</td>
#             </tr>
#     </tbody></table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7592 entries, 0 to 7599
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_paralela  7592 non-null   object
#  1   num_x         7592 non-null   object
#  2   tercero       7592 non-null   object
#  3   cod_op        7592 non-null   object
#  4   op_2021       7592 non-null   object
#  5   apli          7592 non-null   object
#  6   importe       7592 non-null   float64
#  7   exp_gasto     7592 non-null   object
#  8   exp_gestor    7592 non-null   object
#  9   SP            7592 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 910.5+ KB

# %%
pd.pivot_table(df,index = 'SP', columns = 'cod_op', values = ['importe'],margins = True,aggfunc =np.sum)
# Out:
#              importe                                                      \
# cod_op       2001000      2002100     2002200       2002300      2003000
# SP
# 01      9.681616e+07  11855551.00  37418274.0  8.496061e+07  11855551.00
# 02      9.484900e+05     89065.30         NaN  8.594247e+05     89065.30
# 03      5.478874e+06   1716466.93         NaN  3.762398e+06   1716466.93
# 12      3.963160e+03          NaN         NaN  3.963160e+03          NaN
# 17      1.581200e+02          NaN         NaN  1.581200e+02          NaN
# All     1.032476e+08  13661083.23  37418274.0  8.958656e+07  13661083.23
#
#
# cod_op           All
# SP
# 01      2.429062e+08
# 02      1.986045e+06
# 03      1.267421e+07
# 12      7.926320e+03
# 17      3.162400e+02
# All     2.575746e+08

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.groupby(['SP']).sum(['importe']).style.format({"importe": "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_fa7ef_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >importe</th>    </tr>    <tr>        <th class="index_name level0" >SP</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa7ef_level0_row0" class="row_heading level0 row0" >01</th>
#                         <td id="T_fa7ef_row0_col0" class="data row0 col0" >242906153.00</td>
#             </tr>
#             <tr>
#                         <th id="T_fa7ef_level0_row1" class="row_heading level0 row1" >02</th>
#                         <td id="T_fa7ef_row1_col0" class="data row1 col0" >1986045.32</td>
#             </tr>
#             <tr>
#                         <th id="T_fa7ef_level0_row2" class="row_heading level0 row2" >03</th>
#                         <td id="T_fa7ef_row2_col0" class="data row2 col0" >12674206.59</td>
#             </tr>
#             <tr>
#                         <th id="T_fa7ef_level0_row3" class="row_heading level0 row3" >12</th>
#                         <td id="T_fa7ef_row3_col0" class="data row3 col0" >7926.32</td>
#             </tr>
#             <tr>
#                         <th id="T_fa7ef_level0_row4" class="row_heading level0 row4" >17</th>
#                         <td id="T_fa7ef_row4_col0" class="data row4 col0" >316.24</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(df['SP'],df['cod_op'],aggfunc =np.sum, values =df['importe'])
# Out:
# cod_op       2001000       2002100       2002200       2002300       2003000
# SP
# 01     96,816,164.00 11,855,551.00 37,418,274.00 84,960,613.00 11,855,551.00
# 02        948,490.01     89,065.30           NaN    859,424.71     89,065.30
# 03      5,478,874.30  1,716,466.93           NaN  3,762,398.43  1,716,466.93
# 12          3,963.16           NaN           NaN      3,963.16           NaN
# 17            158.12           NaN           NaN        158.12           NaN

# %%
df.style.format({"importe": "{:.1f}"})
df['importe'].sum()
# Out:
# 257574647.47

# %%
df
# Out:
#            num_paralela              num_x       tercero   cod_op  \
# 0     00159222B10008778  00159221310081721             *  2001000
# 1     00159222B10008779  00159221310085846  000B85711828  2002300
# 2     00159222B10008780  00159221310009010             *  2001000
# 3     00159222B10008781  00159221310057742  000B88022793  2002300
# 4     00159222B10008782  00159221310097634             *  2001000
# ...                 ...                ...           ...      ...
# 2945  00159222B10009816                  *  000U88505565  2002300
# 2946  00159222B10009823                  *             *  2001000
# 2947  00159222B10009824                  *  000U88505565  2002300
# 2948  00159222B10009943                  *             *  2001000
# 2949  00159222B10009944                  *  000B30893440  2002300
#
#                 op_2021                    apli    importe     exp_gasto  \
# 0     00159221310081721    20221401  121M2  630 363,000.00  013022100834
# 1     00159221310085846    20221401  121M2  630 363,000.00  013022100834
# 2     00159221310009010    20221401  121M2  630       4.00  101000000166
# 3     00159221310057742    20221401  121M2  630       4.00  013022100187
# 4     00159221310097634    20221401  121M2  630   3,290.00  013022100968
# ...                 ...                     ...        ...           ...
# 2945  00159221310049393  20221417  122N1  22105      12.21  173052100328
# 2946  00159221310044074  20221417  122M1  22105      15.61  173052100337
# 2947  00159221310059903  20221417  122M1  22105      15.61  173052100337
# 2948  00159221310080419  20221417  122M1  22105       2.64  173062100866
# 2949  00159221310085654  20221417  122M1  22105       2.64  173062100866
#
#                exp_gestor  SP
# 0     1991141040001000017  01
# 1     1991141040001000017  01
# 2     1991141040004000069  01
# 3     1991141040004000069  01
# 4     1991141040004000085  01
# ...                   ...  ..
# 2945                       17
# 2946                       17
# 2947                       17
# 2948                       17
# 2949                       17
#
# [2942 rows x 10 columns]
