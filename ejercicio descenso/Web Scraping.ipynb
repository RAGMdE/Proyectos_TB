# %% [markdown]
# # Riesgo de descenso y probabilidad de ascenso en LaLiga

# %% [markdown]
# Se quiere conocer la probabilidad de que un club descienda a Segunda División. Sin embargo, no se disponen de datos históricos, por lo que haremos uso del web scrapping para obtenerlos e implementar un modelo

# %% [markdown]
# ![unnamed.jpg](attachment:unnamed.jpg)

# %% [markdown]
# Para el modelo de **descenso** se utilizarán estas dos webs:
# 1 - [Información de los clubes en cada temporada](https://www.transfermarkt.es/laliga/startseite/wettbewerb/ES1/plus/?saison_id=2020)
# 2 - [Clasificaciones históricas](https://www.transfermarkt.es/laliga/tabelle/wettbewerb/ES1?saison_id=2020)

# %% [markdown]
# ![EgK_m_MWAAACW0Q-RSggNDZ2Y5JSmGsYv0Mjw5I-624x385@Las%20Provincias.jpg](attachment:EgK_m_MWAAACW0Q-RSggNDZ2Y5JSmGsYv0Mjw5I-624x385@Las%20Provincias.jpg)

# %% [markdown]
# Para el modelo de **ascensos** no utilizaremos Machine Learning ("*its not always Machine Learning*"), sino que haremos una aproximación basada en la probabilidad histórica de que un club ascienda, basándonos en los años que lleva en Segunda División. Dicho de otro modo:
#
# ¿Cuántos clubes que llevan 1 año en Segunda han ascendido?
# ¿Cuántos clubes que llevan 2 años en Segunda han ascendido?
# etc.

# %% [markdown]
# ### 1. Modelo de descenso

# %% [markdown]
# Con este código de web scraping se obtiene la información de los equipos en la temporada 2020-2021.

# %%
import pandas as pd
import numpy as np
import requests
import time # time.sleep(0.5)

clubes = pd.DataFrame()

url = 'https://www.transfermarkt.es/laliga/startseite/wettbewerb/ES1/plus/?saison_id=2020'

tables = pd.read_html(requests.get(url,
                               headers={'User-agent': 'Mozilla/5.0'}).text,
                  attrs={"class":"items"})
df = tables[0]
df
# Out:
#     Club               Club.1  name  Equipo  Edad    Extranjeros  \
# 0    NaN         FC Barcelona  33.0     250    21  24,77 mill. €
# 1    NaN       Real Madrid CF  37.0     248    17  21,28 mill. €
# 2    NaN   Atlético de Madrid  39.0     249    21  19,82 mill. €
# 3    NaN           Sevilla FC  38.0     256    17  11,01 mill. €
# 4    NaN        Real Sociedad  38.0     247     6  10,70 mill. €
# 5    NaN        Villarreal CF  36.0     259    13   8,13 mill. €
# 6    NaN          Valencia CF  35.0     247    20   7,97 mill. €
# 7    NaN  Real Betis Balompié  33.0     268    12   6,29 mill. €
# 8    NaN        Athletic Club  32.0     259     1   6,38 mill. €
# 9    NaN            Getafe CF  33.0     254    19   5,15 mill. €
# 10   NaN     RC Celta de Vigo  41.0     243    12   3,80 mill. €
# 11   NaN           Granada CF  44.0     249    17   2,79 mill. €
# 12   NaN           Levante UD  34.0     265    10   3,32 mill. €
# 13   NaN           CA Osasuna  36.0     270     7   2,69 mill. €
# 14   NaN             SD Eibar  34.0     271     9   2,45 mill. €
# 15   NaN     Deportivo Alavés  35.0     256    10   2,28 mill. €
# 16   NaN            SD Huesca  34.0     265     8   1,89 mill. €
# 17   NaN   Real Valladolid CF  39.0     269     9   1,62 mill. €
# 18   NaN             Cádiz CF  41.0     272    16   1,16 mill. €
# 19   NaN             Elche CF  42.0     267    14   1,09 mill. €
# 20   NaN                  NaN   NaN       0     0              0
#
#    ø-Valor de mercado Valor de mercado total
# 0      817,50 mill. €                    NaN
# 1      787,30 mill. €                    NaN
# 2      773,10 mill. €                    NaN
# 3      418,25 mill. €                    NaN
# 4      406,60 mill. €                    NaN
# 5      292,60 mill. €                    NaN
# 6      278,85 mill. €                    NaN
# 7      207,70 mill. €                    NaN
# 8      204,15 mill. €                    NaN
# 9      170,10 mill. €                    NaN
# 10     155,85 mill. €                    NaN
# 11     122,65 mill. €                    NaN
# 12     113,00 mill. €                    NaN
# 13      96,75 mill. €                    NaN
# 14      83,40 mill. €                    NaN
# 15      79,80 mill. €                    NaN
# 16      64,10 mill. €                    NaN
# 17      63,05 mill. €                    NaN
# 18      47,65 mill. €                    NaN
# 19      45,65 mill. €                    NaN
# 20                  -                      -

# %% [markdown]
# Modifica el código anterior para generar un único dataframe con toda la información desde la temporada 2005-06

# %%
clubes = pd.DataFrame()

for temporada in range(2005,2021):
    url = 'https://www.transfermarkt.es/laliga/startseite/wettbewerb/ES1/plus/?saison_id=' + str(temporada)
    tables = pd.read_html(requests.get(url,
                               headers={'User-agent': 'Mozilla/5.0'}).text,
                  attrs={"class":"items"})
    df = tables[0]
    df['Temporada'] = temporada
    clubes = pd.concat([clubes,df],axis=0)
    time.sleep(0.5)

# %%
clubes
# Out:
#     Club                     Club.1  name  Equipo  Edad   Extranjeros  \
# 0    NaN               FC Barcelona  34.0     249    15  9,63 mill. €
# 1    NaN             Real Madrid CF  36.0     250    13  7,82 mill. €
# 2    NaN                Valencia CF  31.0     272    14  6,83 mill. €
# 3    NaN         Atlético de Madrid  31.0     240     8  4,33 mill. €
# 4    NaN  RC Deportivo de La Coruña  33.0     273     8  4,05 mill. €
# ..   ...                        ...   ...     ...   ...           ...
# 16   NaN                  SD Huesca  34.0     265     8  1,89 mill. €
# 17   NaN         Real Valladolid CF  39.0     269     9  1,62 mill. €
# 18   NaN                   Cádiz CF  41.0     272    16  1,16 mill. €
# 19   NaN                   Elche CF  42.0     267    14  1,09 mill. €
# 20   NaN                        NaN   NaN       0     0             0
#
#    ø-Valor de mercado Valor de mercado total  Temporada
# 0      327,50 mill. €                    NaN       2005
# 1      281,60 mill. €                    NaN       2005
# 2      211,75 mill. €                    NaN       2005
# 3      134,15 mill. €                    NaN       2005
# 4      133,65 mill. €                    NaN       2005
# ..                ...                    ...        ...
# 16      64,10 mill. €                    NaN       2020
# 17      63,05 mill. €                    NaN       2020
# 18      47,65 mill. €                    NaN       2020
# 19      45,65 mill. €                    NaN       2020
# 20                  -                      -       2020
#
# [336 rows x 9 columns]

# %% [markdown]
# Limpia el dataframe y obtén uno como este
# ![Captura.PNG](attachment:Captura.PNG)

# %%
clubes1 = clubes.iloc[:,[1,2,3,4,5,8]]
clubes1.columns = ['NaClub','Plantilla','Edad','Extranjeros','Valor','Temporada']
clubes1 = clubes1.loc[~clubes1.Plantilla.isna()]
clubes1['ValorM'] = np.where(clubes1.Valor.str.contains('mil '),1000,1)
clubes1['Valor'] = clubes1.Valor.str.replace(',','.')
clubes1['Valor2'] = clubes1.Valor.str.extract('(^\d*.\d*)').astype('float')
clubes1['Valor2'] = clubes1['Valor2']/clubes1['ValorM']
clubes1['Edad'] = clubes1['Edad']/10
clubes1.loc[clubes1.Temporada==2020]
# Out:
#                  NaClub  Plantilla  Edad  Extranjeros          Valor  \
# 0          FC Barcelona       33.0  25.0           21  24.77 mill. €
# 1        Real Madrid CF       37.0  24.8           17  21.28 mill. €
# 2    Atlético de Madrid       39.0  24.9           21  19.82 mill. €
# 3            Sevilla FC       38.0  25.6           17  11.01 mill. €
# 4         Real Sociedad       38.0  24.7            6  10.70 mill. €
# 5         Villarreal CF       36.0  25.9           13   8.13 mill. €
# 6           Valencia CF       35.0  24.7           20   7.97 mill. €
# 7   Real Betis Balompié       33.0  26.8           12   6.29 mill. €
# 8         Athletic Club       32.0  25.9            1   6.38 mill. €
# 9             Getafe CF       33.0  25.4           19   5.15 mill. €
# 10     RC Celta de Vigo       41.0  24.3           12   3.80 mill. €
# 11           Granada CF       44.0  24.9           17   2.79 mill. €
# 12           Levante UD       34.0  26.5           10   3.32 mill. €
# 13           CA Osasuna       36.0  27.0            7   2.69 mill. €
# 14             SD Eibar       34.0  27.1            9   2.45 mill. €
# 15     Deportivo Alavés       35.0  25.6           10   2.28 mill. €
# 16            SD Huesca       34.0  26.5            8   1.89 mill. €
# 17   Real Valladolid CF       39.0  26.9            9   1.62 mill. €
# 18             Cádiz CF       41.0  27.2           16   1.16 mill. €
# 19             Elche CF       42.0  26.7           14   1.09 mill. €
#
#     Temporada  ValorM  Valor2
# 0        2020       1   24.77
# 1        2020       1   21.28
# 2        2020       1   19.82
# 3        2020       1   11.01
# 4        2020       1   10.70
# 5        2020       1    8.13
# 6        2020       1    7.97
# 7        2020       1    6.29
# 8        2020       1    6.38
# 9        2020       1    5.15
# 10       2020       1    3.80
# 11       2020       1    2.79
# 12       2020       1    3.32
# 13       2020       1    2.69
# 14       2020       1    2.45
# 15       2020       1    2.28
# 16       2020       1    1.89
# 17       2020       1    1.62
# 18       2020       1    1.16
# 19       2020       1    1.09

# %% [markdown]
# Calcula, para cada temporada, el valor relativo de cada club con respecto al valor máximo.
# Primero, crea un dataframe con los valores máximos de cada temporada
# A continuación, normaliza por cada club y temporada, su valor con respecto al máximo

# %%
dfVal = clubes1[['Temporada','Valor2']].groupby('Temporada',as_index=False).max()
dfVal.columns = ['Temporada','VMax']
dfVal
# Out:
#     Temporada   VMax
# 0        2005   9.63
# 1        2006  11.45
# 2        2007  13.68
# 3        2008  12.51
# 4        2009  16.63
# 5        2010  17.28
# 6        2011  17.66
# 7        2012  19.55
# 8        2013  19.17
# 9        2014  19.48
# 10       2015  23.81
# 11       2016  24.92
# 12       2017  33.23
# 13       2018  27.30
# 14       2019  27.69
# 15       2020  24.77

# %%
clubes1 = clubes1.merge(dfVal,how='left',left_on='Temporada',right_on='Temporada')
clubes1
# Out:
#                         NaClub  Plantilla  Edad  Extranjeros         Valor  \
# 0                 FC Barcelona       34.0  24.9           15  9.63 mill. €
# 1               Real Madrid CF       36.0  25.0           13  7.82 mill. €
# 2                  Valencia CF       31.0  27.2           14  6.83 mill. €
# 3           Atlético de Madrid       31.0  24.0            8  4.33 mill. €
# 4    RC Deportivo de La Coruña       33.0  27.3            8  4.05 mill. €
# ..                         ...        ...   ...          ...           ...
# 315           Deportivo Alavés       35.0  25.6           10  2.28 mill. €
# 316                  SD Huesca       34.0  26.5            8  1.89 mill. €
# 317         Real Valladolid CF       39.0  26.9            9  1.62 mill. €
# 318                   Cádiz CF       41.0  27.2           16  1.16 mill. €
# 319                   Elche CF       42.0  26.7           14  1.09 mill. €
#
#      Temporada  ValorM  Valor2   VMax
# 0         2005       1    9.63   9.63
# 1         2005       1    7.82   9.63
# 2         2005       1    6.83   9.63
# 3         2005       1    4.33   9.63
# 4         2005       1    4.05   9.63
# ..         ...     ...     ...    ...
# 315       2020       1    2.28  24.77
# 316       2020       1    1.89  24.77
# 317       2020       1    1.62  24.77
# 318       2020       1    1.16  24.77
# 319       2020       1    1.09  24.77
#
# [320 rows x 9 columns]

# %%
clubes1['ValorRel'] = clubes1['Valor2']/clubes1['VMax']
clubes1
# Out:
#                         NaClub  Plantilla  Edad  Extranjeros         Valor  \
# 0                 FC Barcelona       34.0  24.9           15  9.63 mill. €
# 1               Real Madrid CF       36.0  25.0           13  7.82 mill. €
# 2                  Valencia CF       31.0  27.2           14  6.83 mill. €
# 3           Atlético de Madrid       31.0  24.0            8  4.33 mill. €
# 4    RC Deportivo de La Coruña       33.0  27.3            8  4.05 mill. €
# ..                         ...        ...   ...          ...           ...
# 315           Deportivo Alavés       35.0  25.6           10  2.28 mill. €
# 316                  SD Huesca       34.0  26.5            8  1.89 mill. €
# 317         Real Valladolid CF       39.0  26.9            9  1.62 mill. €
# 318                   Cádiz CF       41.0  27.2           16  1.16 mill. €
# 319                   Elche CF       42.0  26.7           14  1.09 mill. €
#
#      Temporada  ValorM  Valor2   VMax  ValorRel
# 0         2005       1    9.63   9.63  1.000000
# 1         2005       1    7.82   9.63  0.812046
# 2         2005       1    6.83   9.63  0.709242
# 3         2005       1    4.33   9.63  0.449637
# 4         2005       1    4.05   9.63  0.420561
# ..         ...     ...     ...    ...       ...
# 315       2020       1    2.28  24.77  0.092047
# 316       2020       1    1.89  24.77  0.076302
# 317       2020       1    1.62  24.77  0.065402
# 318       2020       1    1.16  24.77  0.046831
# 319       2020       1    1.09  24.77  0.044005
#
# [320 rows x 10 columns]

# %% [markdown]
# Con este código de web scraping, se obtiene la tabla de clasificación para la temporada 2020-21

# %%
url = 'https://www.transfermarkt.es/laliga/tabelle/wettbewerb/ES1?saison_id=2020'

general = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)
df = general[3]
df
# Out:
#      #  Club           Club.1  Unnamed: 3   G   E   P  Goles  +/-  Pto.
# 0    1   NaN  Atlético Madrid          38  26   8   4  67:25   42    86
# 1    2   NaN      Real Madrid          38  25   9   4  67:28   39    84
# 2    3   NaN     FC Barcelona          38  24   7   7  85:38   47    79
# 3    4   NaN       Sevilla FC          38  24   5   9  53:33   20    77
# 4    5   NaN    Real Sociedad          38  17  11  10  59:38   21    62
# 5    6   NaN       Real Betis          38  17  10  11  50:50    0    61
# 6    7   NaN    Villarreal CF          38  15  13  10  60:44   16    58
# 7    8   NaN         RC Celta          38  14  11  13  55:57   -2    53
# 8    9   NaN         Athletic          38  11  13  14  46:42    4    46
# 9   10   NaN       Granada CF          38  13   7  18  47:65  -18    46
# 10  11   NaN       CA Osasuna          38  11  11  16  37:48  -11    44
# 11  12   NaN         Cádiz CF          38  11  11  16  36:58  -22    44
# 12  13   NaN      Valencia CF          38  10  13  15  50:53   -3    43
# 13  14   NaN       Levante UD          38   9  14  15  46:57  -11    41
# 14  15   NaN           Getafe          38   9  11  18  28:43  -15    38
# 15  16   NaN      Dep. Alavés          38   9  11  18  36:57  -21    38
# 16  17   NaN         Elche CF          38   8  12  18  34:55  -21    36
# 17  18   NaN        SD Huesca          38   7  13  18  34:53  -19    34
# 18  19   NaN  Real Valladolid          38   5  16  17  34:57  -23    31
# 19  20   NaN         SD Eibar          38   6  12  20  29:52  -23    30

# %% [markdown]
# Modifica el código anterior para generar un único dataframe con toda la información desde la temporada 2005-06

# %%
clasif = pd.DataFrame()

for temporada in range(2005,2021):
    url = 'https://www.transfermarkt.es/laliga/tabelle/wettbewerb/ES1?saison_id=' + str(temporada)
    general = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)
    df = general[3]
    df['Temporada'] = temporada
    clasif = pd.concat([clasif,df],axis=0)
    time.sleep(0.5)

# %%
clasif
# Out:
#      #  Club           Club.1  Unnamed: 3   G   E   P  Goles  +/-  Pto.  \
# 0    1   NaN     FC Barcelona          38  25   7   6  80:35   45    82
# 1    2   NaN      Real Madrid          38  20  10   8  70:40   30    70
# 2    3   NaN      Valencia CF          38  19  12   7  58:33   25    69
# 3    4   NaN       CA Osasuna          38  21   5  12  49:43    6    68
# 4    5   NaN       Sevilla FC          38  20   8  10  54:39   15    68
# ..  ..   ...              ...         ...  ..  ..  ..    ...  ...   ...
# 15  16   NaN      Dep. Alavés          38   9  11  18  36:57  -21    38
# 16  17   NaN         Elche CF          38   8  12  18  34:55  -21    36
# 17  18   NaN        SD Huesca          38   7  13  18  34:53  -19    34
# 18  19   NaN  Real Valladolid          38   5  16  17  34:57  -23    31
# 19  20   NaN         SD Eibar          38   6  12  20  29:52  -23    30
#
#     Temporada
# 0        2005
# 1        2005
# 2        2005
# 3        2005
# 4        2005
# ..        ...
# 15       2020
# 16       2020
# 17       2020
# 18       2020
# 19       2020
#
# [320 rows x 11 columns]

# %% [markdown]
# Limpia el dataframe y obtén uno como este
# ![1_A61nFx-ivby04ePI3_vAVg.png](attachment:1_A61nFx-ivby04ePI3_vAVg.png)

# %%
clasif1 = clasif.iloc[:,[0,2,3,4,5,6,7,8,9,10]]
clasif1.columns = ['#', 'Club.1', 'Partidos', 'G', 'E', 'P', 'Goles', '+/-', 'Pto.','Temporada']
clasif1
# Out:
#      #           Club.1  Partidos   G   E   P  Goles  +/-  Pto.  Temporada
# 0    1     FC Barcelona        38  25   7   6  80:35   45    82       2005
# 1    2      Real Madrid        38  20  10   8  70:40   30    70       2005
# 2    3      Valencia CF        38  19  12   7  58:33   25    69       2005
# 3    4       CA Osasuna        38  21   5  12  49:43    6    68       2005
# 4    5       Sevilla FC        38  20   8  10  54:39   15    68       2005
# ..  ..              ...       ...  ..  ..  ..    ...  ...   ...        ...
# 15  16      Dep. Alavés        38   9  11  18  36:57  -21    38       2020
# 16  17         Elche CF        38   8  12  18  34:55  -21    36       2020
# 17  18        SD Huesca        38   7  13  18  34:53  -19    34       2020
# 18  19  Real Valladolid        38   5  16  17  34:57  -23    31       2020
# 19  20         SD Eibar        38   6  12  20  29:52  -23    30       2020
#
# [320 rows x 10 columns]

# %% [markdown]
# Une ambos dataframes (información de equipo + clasificación)

# %%
replaces = {'Real Madrid':'Real Madrid CF',
            'RC Celta':'RC Celta de Vigo',
            'RC Deportivo':'RC Deportivo de La Coruña',
            'Getafe':'Getafe CF',
            'Atlético Madrid':'Atlético de Madrid',
            'Athletic':'Athletic Club',
            'Real Betis':'Real Betis Balompié',
            'Racing':'Racing de Santander',
            'Dep. Alavés':'Deportivo Alavés',
            'Recreativo':'Recreativo de Huelva',
            'Gimnàstic':'Gimnàstic de Tarragona',
            'Real Valladolid':'Real Valladolid CF',
            'Real Murcia':'Real Murcia CF',
            'Real Sporting':'Sporting de Gijón'}

# %%
primera = clasif1.replace(replaces).merge(clubes1,how='left',left_on=['Club.1','Temporada'],
                       right_on=['NaClub','Temporada'])
primera
# Out:
#       #              Club.1  Partidos   G   E   P  Goles  +/-  Pto.  \
# 0     1        FC Barcelona        38  25   7   6  80:35   45    82
# 1     2      Real Madrid CF        38  20  10   8  70:40   30    70
# 2     3         Valencia CF        38  19  12   7  58:33   25    69
# 3     4          CA Osasuna        38  21   5  12  49:43    6    68
# 4     5          Sevilla FC        38  20   8  10  54:39   15    68
# ..   ..                 ...       ...  ..  ..  ..    ...  ...   ...
# 315  16    Deportivo Alavés        38   9  11  18  36:57  -21    38
# 316  17            Elche CF        38   8  12  18  34:55  -21    36
# 317  18           SD Huesca        38   7  13  18  34:53  -19    34
# 318  19  Real Valladolid CF        38   5  16  17  34:57  -23    31
# 319  20            SD Eibar        38   6  12  20  29:52  -23    30
#
#      Temporada              NaClub  Plantilla  Edad  Extranjeros  \
# 0         2005        FC Barcelona       34.0  24.9           15
# 1         2005      Real Madrid CF       36.0  25.0           13
# 2         2005         Valencia CF       31.0  27.2           14
# 3         2005          CA Osasuna       25.0  26.0            7
# 4         2005          Sevilla FC       34.0  25.5           11
# ..         ...                 ...        ...   ...          ...
# 315       2020    Deportivo Alavés       35.0  25.6           10
# 316       2020            Elche CF       42.0  26.7           14
# 317       2020           SD Huesca       34.0  26.5            8
# 318       2020  Real Valladolid CF       39.0  26.9            9
# 319       2020            SD Eibar       34.0  27.1            9
#
#             Valor  ValorM  Valor2   VMax  ValorRel
# 0    9.63 mill. €       1    9.63   9.63  1.000000
# 1    7.82 mill. €       1    7.82   9.63  0.812046
# 2    6.83 mill. €       1    6.83   9.63  0.709242
# 3    1.63 mill. €       1    1.63   9.63  0.169263
# 4    2.85 mill. €       1    2.85   9.63  0.295950
# ..            ...     ...     ...    ...       ...
# 315  2.28 mill. €       1    2.28  24.77  0.092047
# 316  1.09 mill. €       1    1.09  24.77  0.044005
# 317  1.89 mill. €       1    1.89  24.77  0.076302
# 318  1.62 mill. €       1    1.62  24.77  0.065402
# 319  2.45 mill. €       1    2.45  24.77  0.098910
#
# [320 rows x 19 columns]

# %%
primera.loc[primera.NaClub.isna()]
# Out:
# Empty DataFrame
# Columns: [#, Club.1, Partidos, G, E, P, Goles, +/-, Pto., Temporada, NaClub, Plantilla, Edad, Extranjeros, Valor, ValorM, Valor2, VMax, ValorRel]
# Index: []

# %% [markdown]
# Genera el dataset para implementar un modelo, con las siguientes columnas:
# * Temporada
# * Equipo
# * Valor relativo
# * Valor relativo de la temporada anterior
# * Valor relativo medio de las últimas dos temporadas
# * Variación del valor con la temporada anterior: (Valor-Valor_1)/Valor_1
# * Posición del año anterior
# * Porcentaje de veces que ha estado en Primera
# * Posición media en sus años en Primera
# * Recién ascendido (Sí/No)
# * Diferencia de goles en la temporada anterior
# * Jugadores en la plantilla
# * Edad media
# * Número de extranjeros
# * Descenso (target)

# %%
datamodel = pd.DataFrame(columns=['Temporada','Equipo','Valor','Valor_1','Delta_Valor','AvgValor_2',
                                  'Position_1',
                                 'VecesPrimera','AvgPosPrimera','RecienAsc',
                                 'DifGoles_1',
                                 'Plantilla','Edad','Extranjeros',
                                 'Descenso'])

for index, row in primera.iterrows():
    if row.Temporada >= 2006:
        
        Temporada = row.Temporada
        Equipo = row['Club.1']
        Valor = row.ValorRel
        try: Valor_1 = primera.loc[(primera.NaClub==row.NaClub) & (primera.Temporada==row.Temporada-1)]['ValorRel'].values[0]
        except: Valor_1 = 0
        try: Delta_Valor = (Valor-Valor_1)/Valor_1
        except: Delta_Valor = 0
        AvgValor_2 = np.mean([Valor_1, Valor])
        try: Position_1 = primera.loc[(primera.NaClub==row.NaClub) & (primera.Temporada==row.Temporada-1)]['#'].values[0]
        except: Position_1 = 21
        VecesPrimera = primera.loc[(primera.NaClub==row.NaClub) & (primera.Temporada<=row.Temporada)].shape[0]/primera.loc[primera.Temporada<=row.Temporada]['Temporada'].nunique()
        AvgPosPrimera = primera.loc[(primera['Club.1']==row['Club.1']) & (primera['Temporada']<row.Temporada)]['#'].mean()
        if np.isnan(AvgPosPrimera): AvgPosPrimera = 21
        RecienAsc = np.where(primera.loc[(primera['Club.1']==row['Club.1']) & (primera['Temporada']==row.Temporada-1)].shape[0]==0, 1, 0)
        try: DifGoles_1 = primera.loc[(primera['Club.1']==row['Club.1']) & (primera['Temporada']==row.Temporada-1)]['+/-'].values[0]
        except: DifGoles_1 = np.nan
        Plantilla = row.Plantilla
        Edad = row.Edad
        Extranjeros = row.Extranjeros
        Descenso = np.where(row['#'] in [18,19,20], 1, 0).item()
        
        dfrow = pd.DataFrame({

        'Temporada':[Temporada],
        'Equipo':[Equipo],
        'Valor':[Valor],
        'Valor_1':[Valor_1],
        'Delta_Valor':[Delta_Valor],
        'AvgValor_2':[AvgValor_2],
        'Position_1':[Position_1],
        'VecesPrimera':[VecesPrimera],
        'AvgPosPrimera':[AvgPosPrimera],
        'RecienAsc':[RecienAsc],
        'DifGoles_1':[DifGoles_1],
        'Plantilla':[Plantilla],
        'Edad':[Edad],
        'Extranjeros':[Extranjeros],
        'Descenso':[Descenso]
        })
        
        datamodel = pd.concat([datamodel,dfrow])

# %%
datamodel
# Out:
#    Temporada              Equipo     Valor   Valor_1  Delta_Valor  AvgValor_2  \
# 0       2006      Real Madrid CF  0.833188  0.812046     0.026036    0.822617
# 0       2006        FC Barcelona  1.000000  1.000000     0.000000    1.000000
# 0       2006          Sevilla FC  0.385153  0.295950     0.301411    0.340551
# 0       2006         Valencia CF  0.615721  0.709242    -0.131861    0.662481
# 0       2006       Villarreal CF  0.317904  0.265836     0.195865    0.291870
# ..       ...                 ...       ...       ...          ...         ...
# 0       2020    Deportivo Alavés  0.092047  0.104370    -0.118070    0.098208
# 0       2020            Elche CF  0.044005  0.000000     0.000000    0.022002
# 0       2020           SD Huesca  0.076302  0.000000     0.000000    0.038151
# 0       2020  Real Valladolid CF  0.065402  0.085590    -0.235876    0.075496
# 0       2020            SD Eibar  0.098910  0.066811     0.480442    0.082861
#
#    Position_1  VecesPrimera  AvgPosPrimera RecienAsc DifGoles_1  Plantilla  \
# 0           2        1.0000       2.000000         0         30       39.0
# 0           1        1.0000       1.000000         0         45       32.0
# 0           5        1.0000       5.000000         0         15       32.0
# 0           3        1.0000       3.000000         0         25       33.0
# 0           7        1.0000       7.000000         0         11       30.0
# ..        ...           ...            ...       ...        ...        ...
# 0          16        0.3750      13.600000         0        -25       35.0
# 0          21        0.1875      14.500000         1        NaN       42.0
# 0          21        0.1250      19.000000         1        NaN       34.0
# 0          13        0.5000      15.857143         0        -11       39.0
# 0          14        0.4375      12.666667         0        -17       34.0
#
#     Edad Extranjeros Descenso
# 0   24.9          15        0
# 0   26.0          18        0
# 0   25.9          15        0
# 0   26.0           9        0
# 0   26.8          16        0
# ..   ...         ...      ...
# 0   25.6          10        0
# 0   26.7          14        0
# 0   26.5           8        1
# 0   26.9           9        1
# 0   27.1           9        1
#
# [300 rows x 15 columns]

# %% [markdown]
# Limpia el dataset anterior y comprueba que es correcto

# %%
datamodel.isnull().sum()
# Out:
# Temporada         0
# Equipo            0
# Valor             0
# Valor_1           0
# Delta_Valor       0
# AvgValor_2        0
# Position_1        0
# VecesPrimera      0
# AvgPosPrimera     0
# RecienAsc         0
# DifGoles_1       45
# Plantilla         0
# Edad              0
# Extranjeros       0
# Descenso          0
# dtype: int64

# %%
for col in datamodel.columns:
    try:
        datamodel[[col]] = datamodel[[col]].astype('float')
    except: print(col)
# Out:
# Equipo

# %% [markdown]
# Realiza la división train-test, selecciona las variables, entrena un modelo y mide el desempeño.
# ¿Qué equipos tienen más probabilidad de descender?

# %%
from sklearn.model_selection import train_test_split
X = datamodel.drop(columns=['Descenso','Equipo','Temporada'])
y = datamodel['Descenso']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
y_train.value_counts()
# Out:
# 0.0    182
# 1.0     28
# Name: Descenso, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0.0    73
# 1.0    17
# Name: Descenso, dtype: int64

# %% [markdown]
# ### Sub-modelo para predecir missings

# %%
dfmiss = pd.concat([X_train, y_train],axis=1)
X = dfmiss.loc[~dfmiss.DifGoles_1.isna()].drop(columns=['DifGoles_1','Descenso'])
y = dfmiss.loc[~dfmiss.DifGoles_1.isna(),'DifGoles_1']

X_trainmiss, X_testmiss, y_trainmiss, y_testmiss = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()
regr.fit(X_trainmiss,y_trainmiss)
y_pred = regr.predict(X_testmiss)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print(mean_squared_error(y_testmiss,y_pred,squared=False))
print(r2_score(y_testmiss,y_pred))
# Out:
# 11.84070099276221
# 0.8336495789254817

# %%
import matplotlib.pyplot as plt
plt.scatter(y_testmiss,y_pred)
plt.axline([0,0],[1,1],color='red')

# %%
pred = regr.predict(X_train.loc[X_train.DifGoles_1.isna(),['Valor','Valor_1','Delta_Valor','AvgValor_2','Position_1','VecesPrimera','AvgPosPrimera','RecienAsc',
             'Plantilla','Edad','Extranjeros']])
pred
# Out:
# array([-20.42, -18.68, -17.86, -18.4 , -17.17, -19.79, -20.95, -18.78,
#        -23.18, -22.17, -18.23, -22.04, -21.72, -18.04, -23.11, -23.1 ,
#        -21.15, -20.59, -21.  , -19.55, -17.8 , -17.25, -23.43, -16.2 ,
#        -18.21, -19.6 , -19.7 , -17.57, -20.53, -18.26])

# %%
X_train.loc[X_train.DifGoles_1.isna(),'DifGoles_1'] = pred

# %%
X_train.isnull().sum()
# Out:
# Valor            0
# Valor_1          0
# Delta_Valor      0
# AvgValor_2       0
# Position_1       0
# VecesPrimera     0
# AvgPosPrimera    0
# RecienAsc        0
# DifGoles_1       0
# Plantilla        0
# Edad             0
# Extranjeros      0
# dtype: int64

# %%
pred2 = regr.predict(X_test.loc[X_test.DifGoles_1.isna(),['Valor','Valor_1','Delta_Valor','AvgValor_2','Position_1','VecesPrimera','AvgPosPrimera','RecienAsc',
             'Plantilla','Edad','Extranjeros']])
X_test.loc[X_test.DifGoles_1.isna(),'DifGoles_1'] = pred2

# %% [markdown]
# #### Modelado

# %%
X_train.shape
# Out:
# (210, 12)

# %%
y_train.value_counts()
# Out:
# 0.0    182
# 1.0     28
# Name: Descenso, dtype: int64

# %%
# Matriz de correlación
import seaborn as sns
import matplotlib.pyplot as plt

correlation = pd.concat([X_train,y_train],axis=1).corr()

mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(180, 20, as_cmap=True)
sns.heatmap(correlation, mask=mask, cmap=cmap, vmax=1, vmin =-1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.show()

# %%
# Importancia de variables
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
plt.barh(X_train.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 12 artists>

# %%
# Balancear 
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)
X_sm, y_sm = sm.fit_resample(X_train,y_train)

# %%
y_sm.value_counts()
# Out:
# 0.0    182
# 1.0    182
# Name: Descenso, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(max_iter=1000)
logisticRegr.fit(X_sm.drop(columns=['Valor_1','AvgValor_2']),y_sm)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logisticRegr.predict(X_test.drop(columns=['Valor_1','AvgValor_2']))

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.77      0.83        73
#          1.0       0.39      0.65      0.49        17
#
#     accuracy                           0.74        90
#    macro avg       0.65      0.71      0.66        90
# weighted avg       0.81      0.74      0.77        90
# array([[56, 17],
#        [ 6, 11]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# 0.0    73
# 1.0    17
# Name: Descenso, dtype: int64

# %%
from sklearn import metrics
metrics.plot_roc_curve(logisticRegr, X_test.drop(columns=['Valor_1','AvgValor_2']),y_test)

# %%
datamodel
# Out:
#     Temporada              Equipo     Valor   Valor_1  Delta_Valor  \
# 0      2006.0      Real Madrid CF  0.833188  0.812046     0.026036
# 0      2006.0        FC Barcelona  1.000000  1.000000     0.000000
# 0      2006.0          Sevilla FC  0.385153  0.295950     0.301411
# 0      2006.0         Valencia CF  0.615721  0.709242    -0.131861
# 0      2006.0       Villarreal CF  0.317904  0.265836     0.195865
# ..        ...                 ...       ...       ...          ...
# 0      2020.0    Deportivo Alavés  0.092047  0.104370    -0.118070
# 0      2020.0            Elche CF  0.044005  0.000000     0.000000
# 0      2020.0           SD Huesca  0.076302  0.000000     0.000000
# 0      2020.0  Real Valladolid CF  0.065402  0.085590    -0.235876
# 0      2020.0            SD Eibar  0.098910  0.066811     0.480442
#
#     AvgValor_2  Position_1  VecesPrimera  AvgPosPrimera  RecienAsc  \
# 0     0.822617         2.0        1.0000       2.000000        0.0
# 0     1.000000         1.0        1.0000       1.000000        0.0
# 0     0.340551         5.0        1.0000       5.000000        0.0
# 0     0.662481         3.0        1.0000       3.000000        0.0
# 0     0.291870         7.0        1.0000       7.000000        0.0
# ..         ...         ...           ...            ...        ...
# 0     0.098208        16.0        0.3750      13.600000        0.0
# 0     0.022002        21.0        0.1875      14.500000        1.0
# 0     0.038151        21.0        0.1250      19.000000        1.0
# 0     0.075496        13.0        0.5000      15.857143        0.0
# 0     0.082861        14.0        0.4375      12.666667        0.0
#
#     DifGoles_1  Plantilla  Edad  Extranjeros  Descenso
# 0         30.0       39.0  24.9         15.0       0.0
# 0         45.0       32.0  26.0         18.0       0.0
# 0         15.0       32.0  25.9         15.0       0.0
# 0         25.0       33.0  26.0          9.0       0.0
# 0         11.0       30.0  26.8         16.0       0.0
# ..         ...        ...   ...          ...       ...
# 0        -25.0       35.0  25.6         10.0       0.0
# 0          NaN       42.0  26.7         14.0       0.0
# 0          NaN       34.0  26.5          8.0       1.0
# 0        -11.0       39.0  26.9          9.0       1.0
# 0        -17.0       34.0  27.1          9.0       1.0
#
# [300 rows x 15 columns]

# %%
pred = regr.predict(datamodel.loc[datamodel.DifGoles_1.isna(),['Valor','Valor_1','Delta_Valor','AvgValor_2','Position_1','VecesPrimera','AvgPosPrimera','RecienAsc',
             'Plantilla','Edad','Extranjeros']])
pred
# Out:
# array([-17.5 , -19.55, -18.75, -18.04, -17.57, -17.86, -17.8 , -19.6 ,
#        -18.26, -18.5 , -18.78, -18.97, -17.56, -17.25, -22.04, -18.4 ,
#        -18.27, -18.68, -19.7 , -23.18, -23.11, -16.2 , -17.17, -23.1 ,
#        -22.7 , -19.79, -20.42, -20.53, -18.21, -19.93, -18.78, -21.15,
#        -21.5 , -23.43, -22.41, -23.26, -18.23, -21.  , -22.17, -21.85,
#        -20.95, -21.72, -20.59, -21.72, -18.13])

# %%
datamodel.loc[datamodel.DifGoles_1.isna(),'DifGoles_1'] = pred

# %%
datamodel['Prob'] = logisticRegr.predict_proba(datamodel.drop(columns=['Temporada',
                                                                      'Equipo',
                                                                      'Valor_1',
                                                                      'AvgValor_2',
                                                                      'Descenso']))[:,1]

# %%
datamodel.loc[datamodel.Temporada==2020,['Temporada','Equipo','Descenso','Prob']].sort_values('Prob')
# Out:
#    Temporada               Equipo  Descenso      Prob
# 0     2020.0         FC Barcelona       0.0  0.001924
# 0     2020.0       Real Madrid CF       0.0  0.017890
# 0     2020.0           Sevilla FC       0.0  0.032245
# 0     2020.0        Villarreal CF       0.0  0.046801
# 0     2020.0   Atlético de Madrid       0.0  0.062584
# 0     2020.0        Athletic Club       0.0  0.092328
# 0     2020.0        Real Sociedad       0.0  0.128668
# 0     2020.0           CA Osasuna       0.0  0.137352
# 0     2020.0            Getafe CF       0.0  0.168159
# 0     2020.0           Granada CF       0.0  0.170420
# 0     2020.0           Levante UD       0.0  0.234672
# 0     2020.0             SD Eibar       1.0  0.369642
# 0     2020.0  Real Betis Balompié       0.0  0.372195
# 0     2020.0          Valencia CF       0.0  0.456544
# 0     2020.0     RC Celta de Vigo       0.0  0.644047
# 0     2020.0            SD Huesca       1.0  0.738064
# 0     2020.0     Deportivo Alavés       0.0  0.825504
# 0     2020.0             Elche CF       0.0  0.904518
# 0     2020.0   Real Valladolid CF       1.0  0.912839
# 0     2020.0             Cádiz CF       0.0  0.936276

# %% [markdown]
# Calcula la probabilidad de descenso para la temporada 2021/22

# %% [markdown]
# Transforma los scores del modelo a probabilidades reales
#
# $$\LARGE P = \frac{P_{mod}\cdot (\frac{P_{desbal}}{P_{bal}})}{P_{mod}\cdot \frac{P_{desbal}}{P_{bal}}+(1-P_{mod})\cdot\frac{1-P_{desbal}}{1-P_{bal}}}$$
# donde
#
# $$P_{mod}= \text{Score del modelo}$$
# $$P_{des}= \text{Ratio desbalance}$$
# $$P_{bal}= 0.5$$

# %%
import pandas as pd
import numpy as np
import requests
import time # time.sleep(0.5)

clubes = pd.DataFrame()

url = 'https://www.transfermarkt.es/laliga/startseite/wettbewerb/ES1/plus/?saison_id=2021'

tables = pd.read_html(requests.get(url,
                               headers={'User-agent': 'Mozilla/5.0'}).text,
                  attrs={"class":"items"})
df = tables[0]
df
# Out:
#     Club               Club.1  name  Equipo       Edad    Extranjeros  \
# 0    NaN       Real Madrid CF  26.0     274         18  30,00 mill. €
# 1    NaN         FC Barcelona  30.0     255         15  21,70 mill. €
# 2    NaN   Atlético de Madrid  22.0     282         19  29,39 mill. €
# 3    NaN           Sevilla FC  26.0     280         19  16,34 mill. €
# 4    NaN        Real Sociedad  28.0     260          7  14,12 mill. €
# 5    NaN        Villarreal CF  26.0     278         12  13,92 mill. €
# 6    NaN          Valencia CF  25.0     245         17  11,95 mill. €
# 7    NaN  Real Betis Balompié  27.0     287         11   8,52 mill. €
# 8    NaN        Athletic Club  25.0     263          0   7,62 mill. €
# 9    NaN            Getafe CF  25.0     261         13   6,01 mill. €
# 10   NaN     RC Celta de Vigo  21.0     278          9   5,94 mill. €
# 11   NaN         RCD Espanyol  26.0     272          6   4,33 mill. €
# 12   NaN           CA Osasuna  24.0     279          4   3,65 mill. €
# 13   NaN           Levante UD  27.0     284          9   3,21 mill. €
# 14   NaN           Granada CF  29.0     275         13   2,97 mill. €
# 15   NaN         RCD Mallorca  27.0     274         13   2,87 mill. €
# 16   NaN     Deportivo Alavés  25.0     270          7   2,67 mill. €
# 17   NaN             Cádiz CF  28.0     280         10   2,22 mill. €
# 18   NaN       Rayo Vallecano  23.0     278         12   2,49 mill. €
# 19   NaN             Elche CF  24.0     293         10   2,02 mill. €
# 20   NaN                  NaN   NaN     513  27,8 Años            223
#
#    ø-Valor de mercado Valor de mercado total
# 0      780,00 mill. €                    NaN
# 1      651,00 mill. €                    NaN
# 2      646,50 mill. €                    NaN
# 3      424,90 mill. €                    NaN
# 4      395,40 mill. €                    NaN
# 5      362,00 mill. €                    NaN
# 6      298,80 mill. €                    NaN
# 7      230,10 mill. €                    NaN
# 8      190,60 mill. €                    NaN
# 9      150,30 mill. €                    NaN
# 10     124,70 mill. €                    NaN
# 11     112,50 mill. €                    NaN
# 12      87,60 mill. €                    NaN
# 13      86,70 mill. €                    NaN
# 14      86,00 mill. €                    NaN
# 15      77,50 mill. €                    NaN
# 16      66,70 mill. €                    NaN
# 17      62,15 mill. €                    NaN
# 18      57,30 mill. €                    NaN
# 19      48,50 mill. €                    NaN
# 20       9,63 mill. €       4,94 mil mill. €

# %%
clubes1 = df.iloc[:,[1,2,3,4,5]]
clubes1.columns = ['NaClub','Plantilla','Edad','Extranjeros','Valor']
clubes1 = clubes1.loc[~clubes1.Plantilla.isna()]

clubes1['ValorM'] = np.where(clubes1.Valor.str.contains('mil '),1000,1)
clubes1['Valor'] = clubes1.Valor.str.replace(',','.')
clubes1['Valor2'] = clubes1.Valor.str.extract('(^\d*.\d*)').astype('float')
clubes1['Valor2'] = clubes1['Valor2']/clubes1['ValorM']
clubes1['Edad'] = clubes1.Edad/10
clubes1['ValorRel'] = clubes1['Valor2']/clubes1['Valor2'].max()
clubes1['Temporada'] = 2021
clubes1
# Out:
#                  NaClub  Plantilla  Edad Extranjeros          Valor  ValorM  \
# 0        Real Madrid CF       26.0  27.4          18  30.00 mill. €       1
# 1          FC Barcelona       30.0  25.5          15  21.70 mill. €       1
# 2    Atlético de Madrid       22.0  28.2          19  29.39 mill. €       1
# 3            Sevilla FC       26.0  28.0          19  16.34 mill. €       1
# 4         Real Sociedad       28.0  26.0           7  14.12 mill. €       1
# 5         Villarreal CF       26.0  27.8          12  13.92 mill. €       1
# 6           Valencia CF       25.0  24.5          17  11.95 mill. €       1
# 7   Real Betis Balompié       27.0  28.7          11   8.52 mill. €       1
# 8         Athletic Club       25.0  26.3           0   7.62 mill. €       1
# 9             Getafe CF       25.0  26.1          13   6.01 mill. €       1
# 10     RC Celta de Vigo       21.0  27.8           9   5.94 mill. €       1
# 11         RCD Espanyol       26.0  27.2           6   4.33 mill. €       1
# 12           CA Osasuna       24.0  27.9           4   3.65 mill. €       1
# 13           Levante UD       27.0  28.4           9   3.21 mill. €       1
# 14           Granada CF       29.0  27.5          13   2.97 mill. €       1
# 15         RCD Mallorca       27.0  27.4          13   2.87 mill. €       1
# 16     Deportivo Alavés       25.0  27.0           7   2.67 mill. €       1
# 17             Cádiz CF       28.0  28.0          10   2.22 mill. €       1
# 18       Rayo Vallecano       23.0  27.8          12   2.49 mill. €       1
# 19             Elche CF       24.0  29.3          10   2.02 mill. €       1
#
#     Valor2  ValorRel  Temporada
# 0    30.00  1.000000       2021
# 1    21.70  0.723333       2021
# 2    29.39  0.979667       2021
# 3    16.34  0.544667       2021
# 4    14.12  0.470667       2021
# 5    13.92  0.464000       2021
# 6    11.95  0.398333       2021
# 7     8.52  0.284000       2021
# 8     7.62  0.254000       2021
# 9     6.01  0.200333       2021
# 10    5.94  0.198000       2021
# 11    4.33  0.144333       2021
# 12    3.65  0.121667       2021
# 13    3.21  0.107000       2021
# 14    2.97  0.099000       2021
# 15    2.87  0.095667       2021
# 16    2.67  0.089000       2021
# 17    2.22  0.074000       2021
# 18    2.49  0.083000       2021
# 19    2.02  0.067333       2021

# %%
datapred = pd.DataFrame(columns=['Temporada','Equipo','Valor','Valor_1','Delta_Valor','AvgValor_2',
                                  'Position_1',
                                 'VecesPrimera','AvgPosPrimera','RecienAsc',
                                 'DifGoles_1',
                                 'Plantilla','Edad','Extranjeros'])

for index,row in clubes1.iterrows():
    Temporada = 2021
    Equipo = row.NaClub
    Valor = row.ValorRel
    try: Valor_1 = primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']==row.Temporada-1)].ValorRel.values[0]
    except: Valor_1 = 0
    AvgValor_2 = np.mean([Valor,Valor_1])
    try: Delta_Valor = (Valor-Valor_1)/Valor_1
    except: Delta_Valor = 0
    try: Position_1 = primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']==row.Temporada-1)]['#'].values[0]
    except: Position_1 = 21
    VecesPrimera = primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']<=row.Temporada)].shape[0]/primera.loc[primera.Temporada<=row.Temporada]['Temporada'].nunique()
    AvgPosPrimera = primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']<row.Temporada)]['#'].mean()
    if np.isnan(AvgPosPrimera): AvgPosPrimera = 21
    RecienAsc = np.where(primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']==row.Temporada-1)].shape[0]==0, 1, 0)
    try: DifGoles_1 = primera.loc[(primera['Club.1']==row['NaClub']) & (primera['Temporada']==row.Temporada-1)]['+/-'].values[0]
    except: DifGoles_1 = np.nan
    Plantilla = row.Plantilla
    Edad = row.Edad
    Extranjeros = row.Extranjeros
    

    dfrow = pd.DataFrame({

    'Temporada':[Temporada],
    'Equipo':[Equipo],
    'Valor':[Valor],
    'Valor_1':[Valor_1],
    'Delta_Valor':[Delta_Valor],
    'AvgValor_2':[AvgValor_2],
    'Position_1':[Position_1],
    'VecesPrimera':[VecesPrimera],
    'AvgPosPrimera':[AvgPosPrimera],
    'RecienAsc':[RecienAsc],
    'DifGoles_1':[DifGoles_1],
    'Plantilla':[Plantilla],
    'Edad':[Edad],
    'Extranjeros':[Extranjeros],
    'Descenso':[Descenso]
    })

    datapred = pd.concat([datapred,dfrow])

# %%
datapred
# Out:
#   Temporada               Equipo     Valor   Valor_1  Delta_Valor  AvgValor_2  \
# 0      2021       Real Madrid CF  1.000000  0.859104     0.164004    0.929552
# 0      2021         FC Barcelona  0.723333  1.000000    -0.276667    0.861667
# 0      2021   Atlético de Madrid  0.979667  0.800161     0.224336    0.889914
# 0      2021           Sevilla FC  0.544667  0.444489     0.225376    0.494578
# 0      2021        Real Sociedad  0.470667  0.431974     0.089571    0.451320
# 0      2021        Villarreal CF  0.464000  0.328220     0.413688    0.396110
# 0      2021          Valencia CF  0.398333  0.321760     0.237982    0.360047
# 0      2021  Real Betis Balompié  0.284000  0.253936     0.118391    0.268968
# 0      2021        Athletic Club  0.254000  0.257570    -0.013859    0.255785
# 0      2021            Getafe CF  0.200333  0.207913    -0.036455    0.204123
# 0      2021     RC Celta de Vigo  0.198000  0.153411     0.290647    0.175706
# 0      2021         RCD Espanyol  0.144333  0.000000     0.000000    0.072167
# 0      2021           CA Osasuna  0.121667  0.108599     0.120328    0.115133
# 0      2021           Levante UD  0.107000  0.134033    -0.201690    0.120517
# 0      2021           Granada CF  0.099000  0.112636    -0.121065    0.105818
# 0      2021         RCD Mallorca  0.095667  0.000000     0.000000    0.047833
# 0      2021     Deportivo Alavés  0.089000  0.092047    -0.033101    0.090523
# 0      2021             Cádiz CF  0.074000  0.046831     0.580155    0.060415
# 0      2021       Rayo Vallecano  0.083000  0.000000     0.000000    0.041500
# 0      2021             Elche CF  0.067333  0.044005     0.530135    0.055669
#
#   Position_1  VecesPrimera  AvgPosPrimera RecienAsc DifGoles_1  Plantilla  \
# 0          2        1.0000       1.875000         0         39       26.0
# 0          3        1.0000       1.562500         0         47       30.0
# 0          1        1.0000       4.187500         0         42       22.0
# 0          4        1.0000       5.312500         0         20       26.0
# 0          5        0.8125      10.153846         0         21       28.0
# 0          7        0.9375       6.666667         0         16       26.0
# 0         13        1.0000       6.437500         0         -3       25.0
# 0          6        0.8125      12.538462         0          0       27.0
# 0          9        1.0000       9.750000         0          4       25.0
# 0         15        0.9375      11.666667         0        -15       25.0
# 0          8        0.6875      12.000000         0         -2       21.0
# 0         21        0.9375      11.933333         1        NaN       26.0
# 0         11        0.7500      12.666667         0        -11       24.0
# 0         14        0.7500      13.833333         0        -11       27.0
# 0         10        0.5000      14.625000         0        -18       29.0
# 0         21        0.5625      11.888889         1        NaN       27.0
# 0         16        0.3750      14.000000         0        -21       25.0
# 0         12        0.1250      15.500000         0        -22       28.0
# 0         21        0.3750      14.000000         1        NaN       23.0
# 0         17        0.1875      15.333333         0        -21       24.0
#
#    Edad Extranjeros  Descenso
# 0  27.4          18       1.0
# 0  25.5          15       1.0
# 0  28.2          19       1.0
# 0  28.0          19       1.0
# 0  26.0           7       1.0
# 0  27.8          12       1.0
# 0  24.5          17       1.0
# 0  28.7          11       1.0
# 0  26.3           0       1.0
# 0  26.1          13       1.0
# 0  27.8           9       1.0
# 0  27.2           6       1.0
# 0  27.9           4       1.0
# 0  28.4           9       1.0
# 0  27.5          13       1.0
# 0  27.4          13       1.0
# 0  27.0           7       1.0
# 0  28.0          10       1.0
# 0  27.8          12       1.0
# 0  29.3          10       1.0

# %%
# Predecir missings en DiffGoles_1
pred = regr.predict(datapred.loc[datapred.DifGoles_1.isna(),['Valor','Valor_1','Delta_Valor','AvgValor_2','Position_1','VecesPrimera','AvgPosPrimera','RecienAsc',
             'Plantilla','Edad','Extranjeros']])
datapred.loc[datapred.DifGoles_1.isna(),'DifGoles_1'] = pred 
datapred
# Out:
#   Temporada               Equipo     Valor   Valor_1  Delta_Valor  AvgValor_2  \
# 0      2021       Real Madrid CF  1.000000  0.859104     0.164004    0.929552
# 0      2021         FC Barcelona  0.723333  1.000000    -0.276667    0.861667
# 0      2021   Atlético de Madrid  0.979667  0.800161     0.224336    0.889914
# 0      2021           Sevilla FC  0.544667  0.444489     0.225376    0.494578
# 0      2021        Real Sociedad  0.470667  0.431974     0.089571    0.451320
# 0      2021        Villarreal CF  0.464000  0.328220     0.413688    0.396110
# 0      2021          Valencia CF  0.398333  0.321760     0.237982    0.360047
# 0      2021  Real Betis Balompié  0.284000  0.253936     0.118391    0.268968
# 0      2021        Athletic Club  0.254000  0.257570    -0.013859    0.255785
# 0      2021            Getafe CF  0.200333  0.207913    -0.036455    0.204123
# 0      2021     RC Celta de Vigo  0.198000  0.153411     0.290647    0.175706
# 0      2021         RCD Espanyol  0.144333  0.000000     0.000000    0.072167
# 0      2021           CA Osasuna  0.121667  0.108599     0.120328    0.115133
# 0      2021           Levante UD  0.107000  0.134033    -0.201690    0.120517
# 0      2021           Granada CF  0.099000  0.112636    -0.121065    0.105818
# 0      2021         RCD Mallorca  0.095667  0.000000     0.000000    0.047833
# 0      2021     Deportivo Alavés  0.089000  0.092047    -0.033101    0.090523
# 0      2021             Cádiz CF  0.074000  0.046831     0.580155    0.060415
# 0      2021       Rayo Vallecano  0.083000  0.000000     0.000000    0.041500
# 0      2021             Elche CF  0.067333  0.044005     0.530135    0.055669
#
#   Position_1  VecesPrimera  AvgPosPrimera RecienAsc DifGoles_1  Plantilla  \
# 0          2        1.0000       1.875000         0         39       26.0
# 0          3        1.0000       1.562500         0         47       30.0
# 0          1        1.0000       4.187500         0         42       22.0
# 0          4        1.0000       5.312500         0         20       26.0
# 0          5        0.8125      10.153846         0         21       28.0
# 0          7        0.9375       6.666667         0         16       26.0
# 0         13        1.0000       6.437500         0         -3       25.0
# 0          6        0.8125      12.538462         0          0       27.0
# 0          9        1.0000       9.750000         0          4       25.0
# 0         15        0.9375      11.666667         0        -15       25.0
# 0          8        0.6875      12.000000         0         -2       21.0
# 0         21        0.9375      11.933333         1     -17.33       26.0
# 0         11        0.7500      12.666667         0        -11       24.0
# 0         14        0.7500      13.833333         0        -11       27.0
# 0         10        0.5000      14.625000         0        -18       29.0
# 0         21        0.5625      11.888889         1     -23.84       27.0
# 0         16        0.3750      14.000000         0        -21       25.0
# 0         12        0.1250      15.500000         0        -22       28.0
# 0         21        0.3750      14.000000         1     -22.78       23.0
# 0         17        0.1875      15.333333         0        -21       24.0
#
#    Edad Extranjeros  Descenso
# 0  27.4          18       1.0
# 0  25.5          15       1.0
# 0  28.2          19       1.0
# 0  28.0          19       1.0
# 0  26.0           7       1.0
# 0  27.8          12       1.0
# 0  24.5          17       1.0
# 0  28.7          11       1.0
# 0  26.3           0       1.0
# 0  26.1          13       1.0
# 0  27.8           9       1.0
# 0  27.2           6       1.0
# 0  27.9           4       1.0
# 0  28.4           9       1.0
# 0  27.5          13       1.0
# 0  27.4          13       1.0
# 0  27.0           7       1.0
# 0  28.0          10       1.0
# 0  27.8          12       1.0
# 0  29.3          10       1.0

# %%
cols = X_sm.drop(columns=['Valor_1','AvgValor_2']).columns.tolist()
cols
# Out:
# ['Valor',
#  'Delta_Valor',
#  'Position_1',
#  'VecesPrimera',
#  'AvgPosPrimera',
#  'RecienAsc',
#  'DifGoles_1',
#  'Plantilla',
#  'Edad',
#  'Extranjeros']

# %%
datapred['Pred'] = logisticRegr.predict_proba(datapred[cols])[:,1]

# %%
datapred
# Out:
#   Temporada               Equipo     Valor   Valor_1  Delta_Valor  AvgValor_2  \
# 0      2021       Real Madrid CF  1.000000  0.859104     0.164004    0.929552
# 0      2021         FC Barcelona  0.723333  1.000000    -0.276667    0.861667
# 0      2021   Atlético de Madrid  0.979667  0.800161     0.224336    0.889914
# 0      2021           Sevilla FC  0.544667  0.444489     0.225376    0.494578
# 0      2021        Real Sociedad  0.470667  0.431974     0.089571    0.451320
# 0      2021        Villarreal CF  0.464000  0.328220     0.413688    0.396110
# 0      2021          Valencia CF  0.398333  0.321760     0.237982    0.360047
# 0      2021  Real Betis Balompié  0.284000  0.253936     0.118391    0.268968
# 0      2021        Athletic Club  0.254000  0.257570    -0.013859    0.255785
# 0      2021            Getafe CF  0.200333  0.207913    -0.036455    0.204123
# 0      2021     RC Celta de Vigo  0.198000  0.153411     0.290647    0.175706
# 0      2021         RCD Espanyol  0.144333  0.000000     0.000000    0.072167
# 0      2021           CA Osasuna  0.121667  0.108599     0.120328    0.115133
# 0      2021           Levante UD  0.107000  0.134033    -0.201690    0.120517
# 0      2021           Granada CF  0.099000  0.112636    -0.121065    0.105818
# 0      2021         RCD Mallorca  0.095667  0.000000     0.000000    0.047833
# 0      2021     Deportivo Alavés  0.089000  0.092047    -0.033101    0.090523
# 0      2021             Cádiz CF  0.074000  0.046831     0.580155    0.060415
# 0      2021       Rayo Vallecano  0.083000  0.000000     0.000000    0.041500
# 0      2021             Elche CF  0.067333  0.044005     0.530135    0.055669
#
#   Position_1  VecesPrimera  AvgPosPrimera RecienAsc DifGoles_1  Plantilla  \
# 0          2        1.0000       1.875000         0         39       26.0
# 0          3        1.0000       1.562500         0         47       30.0
# 0          1        1.0000       4.187500         0         42       22.0
# 0          4        1.0000       5.312500         0         20       26.0
# 0          5        0.8125      10.153846         0         21       28.0
# 0          7        0.9375       6.666667         0         16       26.0
# 0         13        1.0000       6.437500         0         -3       25.0
# 0          6        0.8125      12.538462         0          0       27.0
# 0          9        1.0000       9.750000         0          4       25.0
# 0         15        0.9375      11.666667         0        -15       25.0
# 0          8        0.6875      12.000000         0         -2       21.0
# 0         21        0.9375      11.933333         1     -17.33       26.0
# 0         11        0.7500      12.666667         0        -11       24.0
# 0         14        0.7500      13.833333         0        -11       27.0
# 0         10        0.5000      14.625000         0        -18       29.0
# 0         21        0.5625      11.888889         1     -23.84       27.0
# 0         16        0.3750      14.000000         0        -21       25.0
# 0         12        0.1250      15.500000         0        -22       28.0
# 0         21        0.3750      14.000000         1     -22.78       23.0
# 0         17        0.1875      15.333333         0        -21       24.0
#
#    Edad Extranjeros  Descenso      Pred
# 0  27.4          18       1.0  0.003466
# 0  25.5          15       1.0  0.009361
# 0  28.2          19       1.0  0.002284
# 0  28.0          19       1.0  0.021389
# 0  26.0           7       1.0  0.032970
# 0  27.8          12       1.0  0.012901
# 0  24.5          17       1.0  0.014717
# 0  28.7          11       1.0  0.263738
# 0  26.3           0       1.0  0.053845
# 0  26.1          13       1.0  0.170394
# 0  27.8           9       1.0  0.065767
# 0  27.2           6       1.0  0.142401
# 0  27.9           4       1.0  0.205787
# 0  28.4           9       1.0  0.559997
# 0  27.5          13       1.0  0.783028
# 0  27.4          13       1.0  0.380415
# 0  27.0           7       1.0  0.477250
# 0  28.0          10       1.0  0.425207
# 0  27.8          12       1.0  0.347719
# 0  29.3          10       1.0  0.283082

# %%
def ajustar_prob(pdesb,pbal,pmod):
    num = pmod*(pdesb/pbal)
    den = pmod * (pdesb/pbal) + (1-pmod)*((1-pdesb)/(1-pbal))
    return num/den

# %%
probs = []
for pred in datapred.Pred:
    probs.append(ajustar_prob(3/20,0.5,pred))
probs
# Out:
# [0.0006134204990712474,
#  0.0016646984667489147,
#  0.00040384711189473874,
#  0.003842283058529445,
#  0.0059805344932473345,
#  0.002301042396340119,
#  0.0026290525433843677,
#  0.05945537210462977,
#  0.009943000422204968,
#  0.03497787519861555,
#  0.012270433553589179,
#  0.02846804180576431,
#  0.043725659155169586,
#  0.18340413956368354,
#  0.3890752758895616,
#  0.09775797082224774,
#  0.13875564748648067,
#  0.11547090236340424,
#  0.08598435580079776,
#  0.06514204731016039]

# %%
datapred['Probabilidad'] = probs

# %%
datapred[['Equipo','Pred','Probabilidad']].sort_values('Probabilidad')
# Out:
#                 Equipo      Pred  Probabilidad
# 0   Atlético de Madrid  0.002284      0.000404
# 0       Real Madrid CF  0.003466      0.000613
# 0         FC Barcelona  0.009361      0.001665
# 0        Villarreal CF  0.012901      0.002301
# 0          Valencia CF  0.014717      0.002629
# 0           Sevilla FC  0.021389      0.003842
# 0        Real Sociedad  0.032970      0.005981
# 0        Athletic Club  0.053845      0.009943
# 0     RC Celta de Vigo  0.065767      0.012270
# 0         RCD Espanyol  0.142401      0.028468
# 0            Getafe CF  0.170394      0.034978
# 0           CA Osasuna  0.205787      0.043726
# 0  Real Betis Balompié  0.263738      0.059455
# 0             Elche CF  0.283082      0.065142
# 0       Rayo Vallecano  0.347719      0.085984
# 0         RCD Mallorca  0.380415      0.097758
# 0             Cádiz CF  0.425207      0.115471
# 0     Deportivo Alavés  0.477250      0.138756
# 0           Levante UD  0.559997      0.183404
# 0           Granada CF  0.783028      0.389075

# %% [markdown]
# ### 2. Modelo de ascenso

# %% [markdown]
# Utilizando el mismo dataset anterior, genera un dataframe que indique, para cada equipo descendido, cuánto tiempo tardó en volver a primera división (si es que volvió). Por ejemplo, el Rayo Vallecano desdenció en la temporada 2015-16 y volvió a Primera en la temporada 2018-19 (pasó dos años en "el infierno")

# %%
primera

# %% [markdown]
# Dibuja la curva de probabilidad de ascenso en función de los años que un equipo pase en segunda división

# %%
# Probabilidad de estar un año en 2º

# %%
# Probabilidad de estar dos años en 2º

# %%
# Probabilidad de estar tres años en 2º

# %%
# Probabilidad de estar cuatro años en 2º

# %%
# Probabilidad de estar cinco años en 2º

# %%
# Probabilidad de estar seis años en 2º
